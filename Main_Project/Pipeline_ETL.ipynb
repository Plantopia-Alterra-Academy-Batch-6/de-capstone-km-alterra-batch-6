# %% [markdown]
# # 1. Import Library yang dibutuhkan

# %%
from sqlalchemy import create_engine, inspect
from dotenv import load_dotenv
import os
import pandas as pd
from datetime import datetime
import re
import html
from google.cloud import bigquery
from google.oauth2 import service_account

# %% [markdown]
# ## 1.1 Connect to Database Backend

# %%
load_dotenv()

user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')
database = os.getenv('DB_NAME')

def get_connection():
    return create_engine(
        f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}"
    )

def get_all_tables(engine):
    inspector = inspect(engine)
    return inspector.get_table_names()

def table_to_dataframe(engine, table_name):
    with engine.connect() as connection:
        query = f"SELECT * FROM {table_name}"
        result = connection.execute(query)
        df = pd.DataFrame(result.fetchall(), columns=result.keys())
        return df

engine = get_connection()
print(f"Koneksi ke {host} untuk user {user} sukses dibuat!.")
# Out:
# Koneksi ke 104.198.27.207 untuk user dataengineer sukses dibuat!.

# %% [markdown]
# # 2. Extract

# %% [markdown]
# ## 2.1 Convert Tables to Dataframe

# %%
tables = get_all_tables(engine)
print(f"Tables in the database: {tables}")
# Out:
# Tables in the database: ['admins', 'customize_watering_reminders', 'fertilizers', 'notifications', 'plant_categories', 'plant_characteristics', 'plant_faqs', 'plant_images', 'plant_instruction_categories', 'plant_instructions', 'plant_progresses', 'plant_reminders', 'plants', 'user_plant_histories', 'user_plants', 'users', 'watering_histories']

# %% [markdown]
# ### 2.1.1 All Dataframe

# %%
output_dir = "../data_source_csv"

for table in tables:
    df_variable_name = f"df_{table}"
    globals()[df_variable_name] = table_to_dataframe(engine, table)
    print(f"Menampilkan Dataframe dari tabel: {table}")
    display(globals()[df_variable_name])
    
    csv_filename = os.path.join(output_dir, f"{table}.csv")
    globals()[df_variable_name].to_csv(csv_filename, index=False)
    print(f"Menyimpan Dataframe dari tabel {table} ke {csv_filename} \n")
# Out:
# Menampilkan Dataframe dari tabel: admins
#    id                               name                       email  \
# 0   1  Octaviano Ryan Eka Putra Hartanto  octavianoryan123@gmail.com
# 1   2        Anggita Prameswari Darmawan      aprameswarid@gmail.com
# 2   3                   Anggita Darmawan  anggitadarmawan3@gmail.com
# 3   4                            adminFe        adminfe123@gmail.com
#
#                                             password url_image  \
# 0  $2a$08$wAw9SfEDq6EsDZ7NqYpNnOXE6aV1GB3YUA3zWpT...
# 1  $2a$08$MDwcRNb2SadCbSiUORr6H.QISr6j3ygPcGGhJTp...
# 2  $2a$08$lFrhHW1q9rG/QmrTPeLy9OqQFZtwj/k72HfJ2oq...
# 3  $2a$08$OY4lskcKiJO7zldb.n5t2u7KHYtVBKt9zzR96Zq...
#
#                created_at              updated_at
# 0 2024-05-28 09:13:45.846 2024-05-28 09:13:45.846
# 1 2024-06-03 03:25:41.667 2024-06-03 03:25:41.667
# 2 2024-06-05 01:27:30.592 2024-06-05 01:27:30.592
# 3 2024-06-15 03:50:19.301 2024-06-15 03:50:19.301
# Menyimpan Dataframe dari tabel admins ke ../data_source_csv/admins.csv
#
# Menampilkan Dataframe dari tabel: customize_watering_reminders
#    id  my_plant_id   time  recurring   type created_at updated_at
# 0   8          137  17:00          1  daily 2024-06-17 2024-06-17
# 1   9          153  17:00          1  daily 2024-06-17 2024-06-17
# Menyimpan Dataframe dari tabel customize_watering_reminders ke ../data_source_csv/customize_watering_reminders.csv
#
# Menampilkan Dataframe dari tabel: fertilizers
# Empty DataFrame
# Columns: [id, name, compostition, create_at]
# Index: []
# Menyimpan Dataframe dari tabel fertilizers ke ../data_source_csv/fertilizers.csv
#
# Menampilkan Dataframe dari tabel: notifications
#     id                         title  \
# 0   32  Saatnya meniram tanaman anda
# 1   33   Customize Watering Reminder
# 2   34   Customize Watering Reminder
# 3   35   Customize Watering Reminder
# 4   36   Customize Watering Reminder
# 5   37   Customize Watering Reminder
# 6   38   Customize Watering Reminder
# 7   39   Customize Watering Reminder
# 8   40   Customize Watering Reminder
# 9   41   Customize Watering Reminder
# 10  42   Customize Watering Reminder
# 11  43   Customize Watering Reminder
#
#                                                  body  user_id  is_read  \
# 0                        Saatnya meniram tanaman anda        3        1
# 1   Hiii Octaviano Ryan Eka Putra Hartanto, It's t...        3        1
# 2   Hiii Octaviano Ryan Eka Putra Hartanto, It's t...        3        0
# 3   Hiii Dafa Aldian, It's time to water your plan...       14        0
# 4   Hiii Octaviano Ryan Eka Putra Hartanto, It's t...        3        0
# 5   Hiii Dafa Aldian, It's time to water your plan...       14        0
# 6   Hiii Octaviano Ryan Eka Putra Hartanto, It's t...        3        0
# 7   Hiii Octaviano Ryan Eka Putra Hartanto, It's t...        3        0
# 8   Hiii Dafa Aldian, It's time to water your plan...       14        0
# 9   Hiii Octaviano Ryan Eka Putra Hartanto, It's t...        3        0
# 10  Hiii Dafa Aldian, It's time to water your plan...       14        0
# 11  Hiii Dafa Aldian, It's time to water your plan...       14        0
#
#                 created_at              updated_at  plant_id
# 0  2024-06-17 00:00:00.000 2024-06-17 14:46:42.965        46
# 1  2024-06-17 15:00:00.880 2024-06-18 09:55:41.479        46
# 2  2024-06-18 08:00:03.641 2024-06-18 09:55:54.125        62
# 3  2024-06-18 09:00:04.040 2024-06-18 09:00:04.040        61
# 4  2024-06-18 10:00:03.341 2024-06-18 10:00:03.341        62
# 5  2024-06-18 10:00:05.550 2024-06-18 10:00:05.550        61
# 6  2024-06-18 10:00:06.696 2024-06-18 10:00:06.696        62
# 7  2024-06-18 10:00:08.609 2024-06-18 10:00:08.609        62
# 8  2024-06-18 10:00:09.795 2024-06-18 10:00:09.795        61
# 9  2024-06-18 10:00:10.096 2024-06-18 10:00:10.096        62
# 10 2024-06-18 10:00:11.307 2024-06-18 10:00:11.307        61
# 11 2024-06-18 10:00:12.896 2024-06-18 10:00:12.896        61
# Menyimpan Dataframe dari tabel notifications ke ../data_source_csv/notifications.csv
#
# Menampilkan Dataframe dari tabel: plant_categories
#     id         name                                          image_url  \
# 0    1       Fruits  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 1    2   Succulents  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 2    4  Angiosperms  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 3    5        Herbs  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 4    7       Shrubs  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 5    8        Ferns  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 6    9        Trees  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 7   10     Climbers  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 8   11     Conifers  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 9   12       Annual  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 10  13     Biennals  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 11  14   Bryophytes  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 12  15   Perennials  https://res.cloudinary.com/dxrz0cg5z/image/upl...
#
#                 created_at              updated_at
# 0  2024-05-30 00:45:23.789 2024-06-14 02:51:56.957
# 1  2023-05-28 10:00:00.000 2024-06-14 02:53:30.136
# 2  2023-05-28 10:00:00.000 2024-06-14 02:53:50.500
# 3  2023-05-28 10:00:00.000 2024-06-14 02:54:18.975
# 4  2023-05-28 10:00:00.000 2024-06-14 02:54:50.460
# 5  2024-06-07 07:07:57.671 2024-06-14 02:55:21.187
# 6  2024-06-07 07:18:57.328 2024-06-14 02:56:14.506
# 7  2024-06-14 02:57:03.527 2024-06-14 02:57:03.527
# 8  2024-06-14 02:57:20.947 2024-06-14 02:57:20.947
# 9  2024-06-14 02:57:33.736 2024-06-14 02:57:33.736
# 10 2024-06-14 02:57:46.294 2024-06-14 02:57:46.294
# 11 2024-06-14 02:57:57.152 2024-06-14 02:57:57.152
# 12 2024-06-14 02:58:08.940 2024-06-14 02:58:08.940
# Menyimpan Dataframe dari tabel plant_categories ke ../data_source_csv/plant_categories.csv
#
# Menampilkan Dataframe dari tabel: plant_characteristics
#     id  plant_id  height height_unit  wide   wide_unit leaf_color
# 0   61        61       3       Meter   300  Centimeter        Red
# 1   62        62       2       Meter     1       Meter      Green
# 2   63        63     600  Centimeter   900  Centimeter      Green
# 3   64        64     400  Centimeter   300  Centimeter      Green
# 4   65        65     200  Centimeter   300  Centimeter      Green
# 5   66        66    1200  Centimeter   600  Centimeter      Green
# 6   67        67       2       Meter     1       Meter      Green
# 7   68        68     500  Centimeter   300  Centimeter      Green
# 8   69        69     150  Centimeter    75  Centimeter      Green
# 9   75        75     500  Centimeter   400  Centimeter      Green
# 10  76        76      45  Centimeter    40  Centimeter      Green
# 11  77        77     100  Centimeter    30  Centimeter      Green
# 12  78        78       6       Meter     4       Meter      Green
# 13  79        79      20       Meter     8       Meter      Green
# 14  80        80      60  Centimeter    40  Centimeter      Green
# 15  81        81       1  Centimeter     1  Centimeter     Yellow
# 16  85        85       1  Centimeter     1  Centimeter     Yellow
# 17  86        86       1       Meter     4  Centimeter      Green
# 18  87        87       1  Centimeter     1  Centimeter     Yellow
# Menyimpan Dataframe dari tabel plant_characteristics ke ../data_source_csv/plant_characteristics.csv
#
# Menampilkan Dataframe dari tabel: plant_faqs
#      id  plant_id                                           question  \
# 0    76        61                      <p><em>Mau tanya apa</em></p>
# 1    77        62  <p>Recommendation for fertilizer types and amo...
# 2    78        62  <p>Recommendation for safe pest control to add...
# 3    79        62               <p>How to improve tomato flavor?</p>
# 4    80        62  <p>How to prevent blossom end rot in tomatoes?...
# 5    81        63  <p>Recommendation for fertilizer types and amo...
# 6    82        63  <p>Recommendation for safe pest control to add...
# 7    83        63              <p>Can lavender be grown indoors?</p>
# 8    84        63        <p>How often should lavender be pruned?</p>
# 9    85        64  <p>Recommendation for fertilizer types and amo...
# 10   86        64  <p>Recommendation for safe pest control to add...
# 11   87        64  <p>How often should basil be harvested?&nbsp;H...
# 12   88        65  <p>Recommendation for fertilizer types and amo...
# 13   89        65  <p>Recommendation for safe pest control to add...
# 14   90        65  <p>&nbsp;When should strawberry plants be repl...
# 15   91        65     <p>How to protect strawberries from pests?</p>
# 16   92        66  <p>Recommendation for fertilizer types and amo...
# 17   93        66  <p>Recommendation for safe pest control to add...
# 18   94        66    <p>&nbsp;What are common pests of rosemary?</p>
# 19   95        66           <p>How to propagate rosemary plants?</p>
# 20   96        67  <p>Recommendation for fertilizer types and amo...
# 21   97        67  <p>Recommendation for safe pest control to add...
# 22   98        67  <p>When is the best time to harvest sunflower ...
# 23   99        67  <p>How to deter birds from eating sunflower se...
# 24  100        68  <p>Recommendation for fertilizer types and amo...
# 25  101        68  <p>Recommendation for safe pest control to add...
# 26  102        68  <p>What are common pests and diseases of peppe...
# 27  103        68  <p>How to prevent peppermint from spreading un...
# 28  104        69  <p>Recommendation for fertilizer types and amo...
# 29  105        69  <p>Recommendation for safe pest control to add...
# 30  106        69         <p>How to prevent black spot on roses?</p>
# 31  107        75  <p>What type of fertilizer is recommended for ...
# 32  108        75  <p>Recommendation for fertilizer types and amo...
# 33  109        75  <p>Recommendation for safe pest control to add...
# 34  110        75  <p>How to deal with pests on cucumber plants?</p>
# 35  111        76  <p>What are the recommendations for fertilizer...
# 36  112        76  <p>What are the recommendations for safe pest ...
# 37  113        76  <p>What are common diseases that affect gerani...
# 38  114        76   <p>How do I propagate geraniums effectively?</p>
# 39  115        77  <p>How do I ensure my orchids thrive in low-hu...
# 40  116        77  <p>What are the recommendations for fertilizer...
# 41  117        77  <p>What are the recommendations for safe pest ...
# 42  118        77  <p>Can orchids be grown indoors successfully?</p>
# 43  119        77  <p>&nbsp;How do I encourage orchids to bloom m...
# 44  120        78  <p>What are the recommendations for fertilizer...
# 45  121        78  <p>What are the recommendations for safe pest ...
# 46  122        78  <p>When is the best time to prune lemon trees ...
# 47  123        78  <p>How do I protect lemon trees from pests and...
# 48  124        79  <p>What are the recommendations for fertilizer...
# 49  125        79  <p>What are the recommendations for safe pest ...
# 50  126        79  <p>When is the best time to prune mango trees ...
# 51  127        79  <p>How do I protect mango trees from pests and...
# 52  128        80  <p>What are the recommendations for fertilizer...
# 53  129        80  <p>What are the recommendations for safe pest ...
# 54  130        80               <p>How do I propagate Aloe Vera?</p>
# 55  131        80  <p>Can Aloe Vera tolerate low light conditions...
# 56  132        81           <p>bagaimana cara alang alang tumbuh</p>
# 57  133        85  <p>Bagaimana cara alang alang dapat tumbuh tan...
# 58  134        86                                         <p>idk</p>
# 59  135        87                 <p>How to care for alang-alang</p>
#
#                                                answer              created_at  \
# 0                   <p><em><u>Ya gatauu?</u></em></p> 2024-06-17 08:00:05.709
# 1   <p>Use a balanced 10-10-10 fertilizer at plant... 2024-06-18 02:19:10.655
# 2   <p>Use neem oil or insecticidal soap to manage... 2024-06-18 02:19:10.655
# 3   <p>Provide ample sunlight, avoid over-fertiliz... 2024-06-18 02:19:10.655
# 4   <p>Blossom end rot is caused by calcium defici... 2024-06-18 02:19:10.655
# 5   <p>Use a slow-release fertilizer with a higher... 2024-06-18 02:38:23.623
# 6   <p>Introduce beneficial insects like ladybugs ... 2024-06-18 02:38:23.623
# 7   <p>Lavender can be grown indoors in containers... 2024-06-18 02:38:23.623
# 27           1 2024-06-18 10:23:26.436 2024-06-18 10:23:26.436
# 28           1 2024-06-18 12:00:40.759 2024-06-18 12:00:40.759
# 29           1 2024-06-18 12:06:51.921 2024-06-18 12:06:51.921
# 30           1 2024-06-18 12:16:46.136 2024-06-18 12:16:46.136
# Menyimpan Dataframe dari tabel plant_images ke ../data_source_csv/plant_images.csv
#
# Menampilkan Dataframe dari tabel: plant_instruction_categories
#    id              name                                        description  \
# 0   1  Soil Preparation  In this section, you will learn how to properl...
# 1   2    Planting Seeds  At this stage, you will learn how to properly ...
# 2   3        Plant Care  In this section, you will learn how to properl...
# 3   4           Harvest  At this stage, you will learn how to harvest p...
#
#                                            image_url          created_at  \
# 0  https://res.cloudinary.com/dxrz0cg5z/image/upl... 2023-05-28 10:00:00
# 1  https://res.cloudinary.com/dxrz0cg5z/image/upl... 2023-05-28 10:00:00
# 2  https://res.cloudinary.com/dxrz0cg5z/image/upl... 2023-05-28 10:00:00
# 3  https://res.cloudinary.com/dxrz0cg5z/image/upl... 2023-05-28 10:00:00
#
#                updated_at
# 0 2024-06-14 02:16:24.448
# 1 2024-06-14 02:17:35.928
# 2 2024-06-14 02:18:46.131
# 3 2024-06-14 02:19:50.778
# Menyimpan Dataframe dari tabel plant_instruction_categories ke ../data_source_csv/plant_instruction_categories.csv
#
# Menampilkan Dataframe dari tabel: plant_instructions
#      id  plant_id  step_number            step_title  \
# 0    92        61            1                 Apaya
# 1    93        62            1    Preparing the soil
# 2    94        62            2   Sowing tomato seeds
# 3    95        62            3     Tomato Plant Care
# 4    96        62            4   Harvesting Tomatoes
# ..  ...       ...          ...                   ...
# 56  168        80            4  Harvesting Aloe Vera
# 57  169        81            1                gk tau
# 58  173        85            1          Cara Merawat
# 59  174        86            1    Preparing the Soil
# 60  175        87            1
#
#                                      step_description  \
# 0                           <p><u>enaknya apa</u></p>
# 1   <p>Prepare well-draining soil rich in organic ...
# 2   <p>Sow tomato seeds indoors 6-8 weeks before t...
# 3   <ul><li>Water regularly to keep the soil moist...
# 4   <p>Harvest tomatoes when they are fully colore...
# ..                                                ...
# 56  <p>Harvest mature leaves as needed by cutting ...
# 57                 <p>biarkan tumbuh secara alami</p>
# 58  <p>Biarkan terkena matahari sepanjang hari dan...
# 59  <p>Use fertile soil with good drainage. Incorp...
# 60                 <p>How to care for Alang-Alang</p>
#
#                                        step_image_url additional_tips  \
# 0   https://res.cloudinary.com/dxrz0cg5z/image/upl...            None
# 1   https://res.cloudinary.com/dxrz0cg5z/image/upl...            None
# 2   https://res.cloudinary.com/dxrz0cg5z/image/upl...            None
# 3   https://res.cloudinary.com/dxrz0cg5z/image/upl...            None
# 4   https://res.cloudinary.com/dxrz0cg5z/image/upl...            None
# ..                                                ...             ...
# 56  https://res.cloudinary.com/dxrz0cg5z/image/upl...            None
# 57                                                               None
# 58  https://res.cloudinary.com/dxrz0cg5z/image/upl...            None
# 59  https://res.cloudinary.com/dxrz0cg5z/image/upl...            None
# 60  https://res.cloudinary.com/dxrz0cg5z/image/upl...            None
#
#                 created_at              updated_at  instruction_category_id
# 0  2024-06-17 08:00:05.709 2024-06-17 08:00:05.709                        3
# 1  2024-06-18 02:19:10.655 2024-06-18 02:19:10.655                        1
# 2  2024-06-18 02:19:10.655 2024-06-18 02:19:10.655                        2
# 3  2024-06-18 02:19:10.655 2024-06-18 02:19:10.655                        3
# 4  2024-06-18 02:19:10.655 2024-06-18 02:19:10.655                        4
# ..                     ...                     ...                      ...
# 56 2024-06-18 09:17:12.628 2024-06-18 09:17:12.628                        4
# 57 2024-06-18 10:23:26.436 2024-06-18 10:23:26.436                        2
# 58 2024-06-18 12:00:40.759 2024-06-18 12:00:40.759                        3
# 59 2024-06-18 12:06:51.921 2024-06-18 12:06:51.921                        1
# 60 2024-06-18 12:16:46.136 2024-06-18 12:16:46.136                        3
#
# [61 rows x 10 columns]
# Menyimpan Dataframe dari tabel plant_instructions ke ../data_source_csv/plant_instructions.csv
#
# Menampilkan Dataframe dari tabel: plant_progresses
#    id  plant_id  user_id                                          image_url  \
# 0  23        61       23  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 1  24        61       23  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 2  25        61       23  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 3  26        61       23  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 4  27        75       14  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 5  28        75       14  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 6  29        75       14  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 7  30        75       14  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 8  31        75       14  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 9  32        62       14  https://res.cloudinary.com/dxrz0cg5z/image/upl...
#
#                created_at              updated_at
# 0 2024-06-18 06:24:07.209 2024-06-18 06:24:07.209
# 1 2024-06-18 06:26:09.824 2024-06-18 06:26:09.824
# 2 2024-06-18 06:26:34.694 2024-06-18 06:26:34.694
# 3 2024-06-18 06:28:34.932 2024-06-18 06:28:34.932
# 4 2024-06-18 08:55:18.746 2024-06-18 08:55:18.746
# 5 2024-06-18 09:01:57.549 2024-06-18 09:01:57.549
# 6 2024-06-18 09:04:18.157 2024-06-18 09:04:18.157
# 7 2024-06-18 09:08:23.158 2024-06-18 09:08:23.158
# 8 2024-06-18 09:10:08.294 2024-06-18 09:10:08.294
# 9 2024-06-18 09:10:29.009 2024-06-18 09:10:29.009
# Menyimpan Dataframe dari tabel plant_progresses ke ../data_source_csv/plant_progresses.csv
#
# Menampilkan Dataframe dari tabel: plant_reminders
#     id  plant_id  watering_frequency  each  watering_amount             unit  \
# 0   61        61                   5  Week              300        Liter (l)
# 1   62        62                   3  Week                2        Liter (l)
# 2   63        63                   1  Week                1        Liter (l)
# 3   64        64                   4  Week              500  Milliliter (ml)
# 4   65        65                   2  Week                1        Liter (l)
# 5   66        66                   1  Week              500  Milliliter (ml)
# 6   67        67                   2  Week                1        Liter (l)
# 7   68        68                   2  Week              500  Milliliter (ml)
# 8   69        69                   2  Week                2        Liter (l)
# 9   75        75                   3  Week                1        Liter (l)
# 10  76        76                   1  Week              500  Milliliter (ml)
# 11  77        77                   1  Week              500        Liter (l)
# 12  78        78                   1  Week                5        Liter (l)
# 13  79        79                   1  Week               10        Liter (l)
# 14  80        80                   1  Week              500  Milliliter (ml)
# 15  81        81                   1   Day                1        Liter (l)
# 16  85        85                   1   Day                1  Milliliter (ml)
# 17  86        86                   1   Day                1        Liter (l)
# 18  87        87                   1   Day                1  Milliliter (ml)
#
#    watering_time                             weather_condition  \
# 0          16:30                  Bright Sun,Rainy,Stormy Rain
# 1          09:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 2          08:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 3          08:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 4          07:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 5          07:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 6          08:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 7          08:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 8          08:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 9          07:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 10         06:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 11         07:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 12         06:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 13         06:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 14         07:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 15         01:00                                    Bright Sun
# 16         01:00                                    Bright Sun
# 17         12:00                                    Bright Sun
# 18         01:00                                    Bright Sun
#
#                                 condition_description              created_at  \
# 0                                    Sun,Rainy,Stormy 2024-06-17 08:00:05.718
# 1   Water in the early morning or late afternoon.,... 2024-06-18 02:19:10.663
# 2   Water early in the morning.,Maintain regular w... 2024-06-18 02:38:23.630
# 3   Water in the early morning.,Maintain regular w... 2024-06-18 02:53:10.675
# 4   Water in the early morning.,Maintain regular w... 2024-06-18 04:11:31.785
# 8   <p>Roses are ornamental flowering plants known...         0
# 9   <p>Cucumbers are climbing plants known for the...         0
# 10  <p>Geraniums are flowering plants known for th...         0
# 11  <p>Orchids are exotic flowering plants known f...         0
# 12  <p>Lemon trees are citrus plants known for the...         0
# 13  <p>Mango trees are tropical fruit trees known ...         0
# 14  <p>Aloe Vera is a succulent plant known for it...         0
# 15                       <p>Anggap aja Rumput lah</p>         0
# 16  <p>Alang-alang adalah rumput perennial yang se...         0
# 17  <p>"<strong>Cabe</strong>" is a term that typi...         0
# 18  <p>Alang-alang adalah rumput perennial yang se...         0
#
#     harvest_duration sunlight planting_time  plant_category_id  \
# 0                  6  Partsun        Autumn                 11
# 1                  3  Fullsun        Spring                  1
# 2                  6  Fullsun        Summer                  7
# 3                  1  Partsun        Spring                  5
# 4                  3    Shade        Spring                  1
# 5                  1  Fullsun        Spring                  5
# 6                  3  Fullsun        Spring                 12
# 7                  3  Partsun        Spring                  5
# 8                  6  Fullsun        Spring                  7
# 9                  3  Fullsun        Spring                  1
# 10                 3  Partsun        Spring                 15
# 11                 3    Shade        Spring                 15
# 12                 9  Fullsun        Spring                  1
# 13                12  Fullsun        Spring                  1
# 14                12  Fullsun        Summer                  2
# 15                 1  Fullsun        Summer                 15
# 16                 1  Fullsun        Summer                 15
# 17                 1  Partsun        Summer                  1
# 18                 1  Fullsun        Summer                 15
#
#    climate_condition  plant_characteristic_id              created_at  \
# 0                Wet                        0 2024-06-17 08:00:05.709
# 1                Dry                        0 2024-06-18 02:19:10.655
# 2                Dry                        0 2024-06-18 02:38:23.623
# 3                Wet                        0 2024-06-18 02:53:10.666
# 4                Dry                        0 2024-06-18 04:11:31.777
# 5                Dry                        0 2024-06-18 04:42:09.521
# 6                Dry                        0 2024-06-18 04:58:57.702
# 7                Wet                        0 2024-06-18 05:14:53.014
# 8                Wet                        0 2024-06-18 05:33:37.917
# 9                Wet                        0 2024-06-18 06:04:39.375
# 10               Wet                        0 2024-06-18 08:00:50.598
# 11               Dry                        0 2024-06-18 08:18:24.765
# 12               Dry                        0 2024-06-18 08:35:56.737
# 13               Dry                        0 2024-06-18 09:05:40.900
# 14               Dry                        0 2024-06-18 09:17:12.628
# 15               Dry                        0 2024-06-18 10:23:26.436
# 16               Dry                        0 2024-06-18 12:00:40.759
# 17               Dry                        0 2024-06-18 12:06:51.921
# 18               Dry                        0 2024-06-18 12:16:46.136
#
#                 updated_at                                    additional_tips
# 0  2024-06-17 08:00:05.709  <p><strong><em><u>Tipsnya ya gituu</u></em></s...
# 1  2024-06-18 02:19:10.655  <ul><li>Support plants with stakes or cages to...
# 2  2024-06-18 02:38:23.623  <ul><li>Mulch around plants to retain moisture...
# 3  2024-06-18 02:53:10.666  <ul><li>Regularly pinch off flower buds to pro...
# 4  2024-06-18 04:11:31.777  <ul><li>Provide good air circulation to preven...
# 5  2024-06-18 04:42:09.521  <ul><li>Protect from frost in colder climates ...
# 6  2024-06-18 04:58:57.702  <ul><li>Deadhead spent flowers to encourage co...
# 13  dH_c2I-PSiilsZsWbIqsvV:APA91bE4CJyKvFYT7XJ1pxb...
# 14  dH_c2I-PSiilsZsWbIqsvV:APA91bHYcZEhXgk-SJZQ-w0...
# 15  dH_c2I-PSiilsZsWbIqsvV:APA91bFSrvn1Ok1eYpAVUlp...
# 16  enYsCpA4SyCfztWDhjcv1g:APA91bFDdtlOp9MifpsiTrc...
# 17  dF9WdTr0QmmIPpYVbxLjZJ:APA91bECbPFLP9dFrsoDLH7...
# 18  enYsCpA4SyCfztWDhjcv1g:APA91bG4ox9yyUzwYPn5-dc...
# 19  dF9WdTr0QmmIPpYVbxLjZJ:APA91bECbPFLP9dFrsoDLH7...
# 20  dH_c2I-PSiilsZsWbIqsvV:APA91bFSrvn1Ok1eYpAVUlp...
# 21  fGlstT-gQ0O4svve3G3iBZ:APA91bGWezWesVpmQ5kv9m-...
# 22  fGlstT-gQ0O4svve3G3iBZ:APA91bFyg33gkyND-oBOpYL...
# Menyimpan Dataframe dari tabel users ke ../data_source_csv/users.csv
#
# Menampilkan Dataframe dari tabel: watering_histories
#    id  plant_id  user_id              created_at              updated_at
# 0   7        62        3 2024-06-18 10:28:04.543 2024-06-18 10:28:04.543
# Menyimpan Dataframe dari tabel watering_histories ke ../data_source_csv/watering_histories.csv

# %% [markdown]
# # 3. Transform

# %% [markdown]
# ## 3.1 Cleaning Data

# %%
def remove_html_tags(text):
    """Fungsi untuk menghapus tag HTML dan entitas HTML dari teks."""
    # Menghapus tag HTML
    clean = re.compile('<.*?>')
    text = re.sub(clean, '', text)
    # Menghapus entitas HTML
    text = html.unescape(text)
    return text

def cleanse_dataframe(df):
    print("Memeriksa missing values...")
    
    # Mengisi missing values berdasarkan tipe data kolom
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype == 'int64' or df[col].dtype == 'float64':
                print(f"Mengisi missing values di kolom '{col}' dengan 0...")
                df[col].fillna(0, inplace=True)
            elif df[col].dtype == 'object' or df[col].dtype.name == 'category':
                print(f"Mengisi missing values di kolom '{col}' dengan '-'...")
                df[col].fillna('-', inplace=True)
            elif pd.api.types.is_datetime64_any_dtype(df[col]):
                print(f"Mengisi missing values di kolom '{col}' dengan tanggal hari ini...")
                df[col].fillna(pd.Timestamp('today'), inplace=True)
    
    print("Membersihkan tag HTML dari kolom teks...")
    # Membersihkan tag HTML dan entitas HTML dari kolom teks (object atau category)
    for col in df.columns:
        if df[col].dtype == 'object' or df[col].dtype.name == 'category':
            print(f"Membersihkan tag HTML di kolom '{col}'...")
            df[col] = df[col].apply(lambda x: remove_html_tags(x) if pd.notnull(x) else x)
    
    print("Memeriksa duplikasi...")
    duplicate_rows = df.duplicated().sum()
    print(f"Jumlah baris duplikat: {duplicate_rows}")
    
    if duplicate_rows > 0:
        print("Menghapus baris duplikat...")
        df.drop_duplicates(inplace=True)

    return df

# %%
def cleanse_dataframe_fact(df):
    print("Memeriksa missing values...")
    
    # Mengisi missing values berdasarkan tipe data kolom
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype == 'int64' or df[col].dtype == 'float64':
                print(f"Mengisi missing values di kolom '{col}' dengan -1...")
                df[col].fillna(-1, inplace=True)
    
    return df

# %%
for table in tables:
    df_variable_name = f"df_{table}"
    
    # Cleansing DataFrame
    globals()[df_variable_name] = cleanse_dataframe(globals()[df_variable_name])
# Out:
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'email'...
# Membersihkan tag HTML di kolom 'password'...
# Membersihkan tag HTML di kolom 'url_image'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'time'...
# Membersihkan tag HTML di kolom 'type'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'id'...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'compostition'...
# Membersihkan tag HTML di kolom 'create_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'title'...
# Membersihkan tag HTML di kolom 'body'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'image_url'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'height_unit'...
# Membersihkan tag HTML di kolom 'wide_unit'...
# Membersihkan tag HTML di kolom 'leaf_color'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'question'...
# Membersihkan tag HTML di kolom 'answer'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'file_name'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'description'...
# Membersihkan tag HTML di kolom 'image_url'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Mengisi missing values di kolom 'additional_tips' dengan '-'...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'step_title'...
# Membersihkan tag HTML di kolom 'step_description'...
# Membersihkan tag HTML di kolom 'step_image_url'...
# Membersihkan tag HTML di kolom 'additional_tips'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'image_url'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'each'...
# Membersihkan tag HTML di kolom 'unit'...
# Membersihkan tag HTML di kolom 'watering_time'...
# Membersihkan tag HTML di kolom 'weather_condition'...
# Membersihkan tag HTML di kolom 'condition_description'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'description'...
# Membersihkan tag HTML di kolom 'sunlight'...
# Membersihkan tag HTML di kolom 'planting_time'...
# Membersihkan tag HTML di kolom 'climate_condition'...
# Membersihkan tag HTML di kolom 'additional_tips'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'plant_name'...
# Membersihkan tag HTML di kolom 'plant_category'...
# Membersihkan tag HTML di kolom 'plant_image_url'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Mengisi missing values di kolom 'last_watered_at' dengan '-'...
# Mengisi missing values di kolom 'customize_name' dengan '-'...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'last_watered_at'...
# Membersihkan tag HTML di kolom 'customize_name'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'last_watered_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Mengisi missing values di kolom 'fcm_token' dengan '-'...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'email'...
# Membersihkan tag HTML di kolom 'password'...
# Membersihkan tag HTML di kolom 'otp'...
# Membersihkan tag HTML di kolom 'url_image'...
# Membersihkan tag HTML di kolom 'fcm_token'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini

# %% [markdown]
# ## 3.2 Informasi Dataframe

# %%
def info_dataframe(df):
    print("Menampilkan Informasi Field di tiap Dataframe")
    info_dataframe = df.info()
    print(info_dataframe)
    
    return df

# %%
for table in tables:
    df_variable_name = f"df_{table}"
    
    # Informasi DataFrame
    globals()[df_variable_name] = info_dataframe(globals()[df_variable_name])
# Out:
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          4 non-null      int64
#  1   name        4 non-null      category
#  2   email       4 non-null      category
#  3   password    4 non-null      category
#  4   url_image   4 non-null      category
#  5   created_at  4 non-null      datetime64[ns]
#  6   updated_at  4 non-null      datetime64[ns]
# dtypes: category(4), datetime64[ns](2), int64(1)
# memory usage: 968.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2 non-null      int64
#  1   my_plant_id  2 non-null      int64
#  2   time         2 non-null      category
#  3   recurring    2 non-null      int64
#  4   type         2 non-null      category
#  5   created_at   2 non-null      datetime64[ns]
#  6   updated_at   2 non-null      datetime64[ns]
# dtypes: category(2), datetime64[ns](2), int64(3)
# memory usage: 444.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            0 non-null      category
#  1   name          0 non-null      category
#  2   compostition  0 non-null      category
#  3   create_at     0 non-null      category
# dtypes: category(4)
# memory usage: 556.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          12 non-null     int64
#  1   title       12 non-null     category
#  2   body        12 non-null     category
#  3   user_id     12 non-null     int64
#  4   is_read     12 non-null     int64
#  5   created_at  12 non-null     datetime64[ns]
#  6   updated_at  12 non-null     datetime64[ns]
#  7   plant_id    12 non-null     int64
# dtypes: category(2), datetime64[ns](2), int64(4)
# memory usage: 1.0 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          13 non-null     int64
#  1   name        13 non-null     category
#  2   image_url   13 non-null     category
#  3   created_at  13 non-null     datetime64[ns]
#  4   updated_at  13 non-null     datetime64[ns]
# dtypes: category(2), datetime64[ns](2), int64(1)
# memory usage: 1.7 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           19 non-null     int64
#  1   plant_id     19 non-null     int64
#  2   height       19 non-null     int64
#  3   height_unit  19 non-null     category
#  4   wide         19 non-null     int64
#  5   wide_unit    19 non-null     category
#  6   leaf_color   19 non-null     category
# dtypes: category(3), int64(4)
# memory usage: 1.1 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          60 non-null     int64
#  1   plant_id    60 non-null     int64
#  2   question    60 non-null     category
#  3   answer      60 non-null     category
#  4   created_at  60 non-null     datetime64[ns]
#  5   updated_at  60 non-null     datetime64[ns]
# dtypes: category(2), datetime64[ns](2), int64(2)
# memory usage: 6.0 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          31 non-null     int64
#  1   plant_id    31 non-null     int64
#  2   file_name   31 non-null     category
#  3   is_primary  31 non-null     int64
#  4   created_at  31 non-null     datetime64[ns]
#  5   updated_at  31 non-null     datetime64[ns]
# dtypes: category(1), datetime64[ns](2), int64(3)
# memory usage: 2.7 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4 non-null      int64
#  1   name         4 non-null      category
#  2   description  4 non-null      category
#  3   image_url    4 non-null      category
#  4   created_at   4 non-null      datetime64[ns]
#  5   updated_at   4 non-null      datetime64[ns]
# dtypes: category(3), datetime64[ns](2), int64(1)
# memory usage: 848.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       61 non-null     int64
#  1   plant_id                 61 non-null     int64
#  2   step_number              61 non-null     int64
#  3   step_title               61 non-null     category
#  4   step_description         61 non-null     category
#  5   step_image_url           61 non-null     category
#  6   additional_tips          61 non-null     category
#  7   created_at               61 non-null     datetime64[ns]
#  8   updated_at               61 non-null     datetime64[ns]
#  9   instruction_category_id  61 non-null     int64
# dtypes: category(4), datetime64[ns](2), int64(4)
# memory usage: 10.9 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          10 non-null     int64
#  1   plant_id    10 non-null     int64
#  2   user_id     10 non-null     int64
#  3   image_url   10 non-null     category
#  4   created_at  10 non-null     datetime64[ns]
#  5   updated_at  10 non-null     datetime64[ns]
# dtypes: category(1), datetime64[ns](2), int64(3)
# memory usage: 918.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     19 non-null     int64
#  1   plant_id               19 non-null     int64
#  2   watering_frequency     19 non-null     int64
#  3   each                   19 non-null     category
#  4   watering_amount        19 non-null     int64
#  5   unit                   19 non-null     category
#  6   watering_time          19 non-null     category
#  7   weather_condition      19 non-null     category
#  8   condition_description  19 non-null     category
#  9   created_at             19 non-null     datetime64[ns]
#  10  updated_at             19 non-null     datetime64[ns]
# dtypes: category(5), datetime64[ns](2), int64(4)
# memory usage: 2.5 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       19 non-null     int64
#  1   name                     19 non-null     category
#  2   description              19 non-null     category
#  3   is_toxic                 19 non-null     int64
#  4   harvest_duration         19 non-null     int64
#  5   sunlight                 19 non-null     category
#  6   planting_time            19 non-null     category
#  7   plant_category_id        19 non-null     int64
#  8   climate_condition        19 non-null     category
#  9   plant_characteristic_id  19 non-null     int64
#  10  created_at               19 non-null     datetime64[ns]
#  11  updated_at               19 non-null     datetime64[ns]
#  12  additional_tips          19 non-null     category
# dtypes: category(6), datetime64[ns](2), int64(5)
# memory usage: 3.7 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               29 non-null     int64
#  1   user_id          29 non-null     int64
#  2   plant_id         29 non-null     int64
#  3   plant_name       29 non-null     category
#  4   plant_category   29 non-null     category
#  5   plant_image_url  29 non-null     category
#  6   created_at       29 non-null     datetime64[ns]
#  7   updated_at       29 non-null     datetime64[ns]
# dtypes: category(3), datetime64[ns](2), int64(3)
# memory usage: 2.3 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               10 non-null     int64
#  1   user_id          10 non-null     int64
#  2   plant_id         10 non-null     int64
#  3   created_at       10 non-null     datetime64[ns]
#  4   updated_at       10 non-null     datetime64[ns]
#  5   last_watered_at  0 non-null      datetime64[ns]
#  6   customize_name   10 non-null     category
# dtypes: category(1), datetime64[ns](3), int64(3)
# memory usage: 974.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          23 non-null     int64
#  1   name        23 non-null     category
#  2   email       23 non-null     category
#  3   password    23 non-null     category
#  4   is_active   23 non-null     int64
#  5   otp         23 non-null     category
#  6   url_image   23 non-null     category
#  7   created_at  23 non-null     datetime64[ns]
#  8   updated_at  23 non-null     datetime64[ns]
#  9   fcm_token   23 non-null     category
# dtypes: category(6), datetime64[ns](2), int64(2)
# memory usage: 4.6 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1 non-null      int64
#  1   plant_id    1 non-null      int64
#  2   user_id     1 non-null      int64
#  3   created_at  1 non-null      datetime64[ns]
#  4   updated_at  1 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 168.0 bytes
# None

# %% [markdown]
# ## 3.3 Change Type Data

# %%
def change_type_data(df):
    # Memastikan tipe data yang benar
    print(f"Memastikan tipe data yang benar...")
    for column in df.columns:
        if df[column].dtype == 'object':
            df[column] = df[column].astype('category')
        elif df[column].dtype == 'float64':
            df[column] = df[column].astype('int64')
    
    # Pastikan kolom tanggal diubah menjadi datetime dengan format '%Y-%m-%d %H:%M'
    date_columns = ['created_at', 'updated_at', 'last_watered_at']
    for column in date_columns:
        if column in df.columns:
            print(f"Mengonversi kolom '{column}' menjadi datetime dengan format '%Y-%m-%d %H:%M'...")
            df[column] = pd.to_datetime(df[column], errors='coerce', format='%Y-%m-%d %H:%M')
    
    # Isi nilai NULL di kolom created_at jika ada
    if 'created_at' in df.columns:
        df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
    if 'updated_at' in df.columns:
        df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
    
    return df

# %%
dataframes = []  # List untuk menyimpan nama dataframe

for table in tables:
    df_variable_name = f"df_{table}"
    
    # Cleansing DataFrame
    globals()[df_variable_name] = change_type_data(globals()[df_variable_name])
    
    # Tambahkan nama dataframe ke dalam list
    dataframes.append(df_variable_name)

# Output untuk verifikasi
print(dataframes)
# Out:
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'last_watered_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# ['df_admins', 'df_customize_watering_reminders', 'df_fertilizers', 'df_notifications', 'df_plant_categories', 'df_plant_characteristics', 'df_plant_faqs', 'df_plant_images', 'df_plant_instruction_categories', 'df_plant_instructions', 'df_plant_progresses', 'df_plant_reminders', 'df_plants', 'df_user_plant_histories', 'df_user_plants', 'df_users', 'df_watering_histories']
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini

# %% [markdown]
# ### 3.3.1 Menampilkan Informasi Dataframe Kembali

# %%
for table in dataframes:
    df_variable_name = f"{table}"
    
    # Informasi DataFrame
    globals()[df_variable_name] = info_dataframe(globals()[df_variable_name])
# Out:
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          4 non-null      int64
#  1   name        4 non-null      category
#  2   email       4 non-null      category
#  3   password    4 non-null      category
#  4   url_image   4 non-null      category
#  5   created_at  4 non-null      datetime64[ns]
#  6   updated_at  4 non-null      datetime64[ns]
# dtypes: category(4), datetime64[ns](2), int64(1)
# memory usage: 968.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2 non-null      int64
#  1   my_plant_id  2 non-null      int64
#  2   time         2 non-null      category
#  3   recurring    2 non-null      int64
#  4   type         2 non-null      category
#  5   created_at   2 non-null      datetime64[ns]
#  6   updated_at   2 non-null      datetime64[ns]
# dtypes: category(2), datetime64[ns](2), int64(3)
# memory usage: 444.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            0 non-null      category
#  1   name          0 non-null      category
#  2   compostition  0 non-null      category
#  3   create_at     0 non-null      category
# dtypes: category(4)
# memory usage: 556.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          12 non-null     int64
#  1   title       12 non-null     category
#  2   body        12 non-null     category
#  3   user_id     12 non-null     int64
#  4   is_read     12 non-null     int64
#  5   created_at  12 non-null     datetime64[ns]
#  6   updated_at  12 non-null     datetime64[ns]
#  7   plant_id    12 non-null     int64
# dtypes: category(2), datetime64[ns](2), int64(4)
# memory usage: 1.0 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          13 non-null     int64
#  1   name        13 non-null     category
#  2   image_url   13 non-null     category
#  3   created_at  13 non-null     datetime64[ns]
#  4   updated_at  13 non-null     datetime64[ns]
# dtypes: category(2), datetime64[ns](2), int64(1)
# memory usage: 1.7 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           19 non-null     int64
#  1   plant_id     19 non-null     int64
#  2   height       19 non-null     int64
#  3   height_unit  19 non-null     category
#  4   wide         19 non-null     int64
#  5   wide_unit    19 non-null     category
#  6   leaf_color   19 non-null     category
# dtypes: category(3), int64(4)
# memory usage: 1.1 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          60 non-null     int64
#  1   plant_id    60 non-null     int64
#  2   question    60 non-null     category
#  3   answer      60 non-null     category
#  4   created_at  60 non-null     datetime64[ns]
#  5   updated_at  60 non-null     datetime64[ns]
# dtypes: category(2), datetime64[ns](2), int64(2)
# memory usage: 6.0 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          31 non-null     int64
#  1   plant_id    31 non-null     int64
#  2   file_name   31 non-null     category
#  3   is_primary  31 non-null     int64
#  4   created_at  31 non-null     datetime64[ns]
#  5   updated_at  31 non-null     datetime64[ns]
# dtypes: category(1), datetime64[ns](2), int64(3)
# memory usage: 2.7 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4 non-null      int64
#  1   name         4 non-null      category
#  2   description  4 non-null      category
#  3   image_url    4 non-null      category
#  4   created_at   4 non-null      datetime64[ns]
#  5   updated_at   4 non-null      datetime64[ns]
# dtypes: category(3), datetime64[ns](2), int64(1)
# memory usage: 848.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       61 non-null     int64
#  1   plant_id                 61 non-null     int64
#  2   step_number              61 non-null     int64
#  3   step_title               61 non-null     category
#  4   step_description         61 non-null     category
#  5   step_image_url           61 non-null     category
#  6   additional_tips          61 non-null     category
#  7   created_at               61 non-null     datetime64[ns]
#  8   updated_at               61 non-null     datetime64[ns]
#  9   instruction_category_id  61 non-null     int64
# dtypes: category(4), datetime64[ns](2), int64(4)
# memory usage: 10.9 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          10 non-null     int64
#  1   plant_id    10 non-null     int64
#  2   user_id     10 non-null     int64
#  3   image_url   10 non-null     category
#  4   created_at  10 non-null     datetime64[ns]
#  5   updated_at  10 non-null     datetime64[ns]
# dtypes: category(1), datetime64[ns](2), int64(3)
# memory usage: 918.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     19 non-null     int64
#  1   plant_id               19 non-null     int64
#  2   watering_frequency     19 non-null     int64
#  3   each                   19 non-null     category
#  4   watering_amount        19 non-null     int64
#  5   unit                   19 non-null     category
#  6   watering_time          19 non-null     category
#  7   weather_condition      19 non-null     category
#  8   condition_description  19 non-null     category
#  9   created_at             19 non-null     datetime64[ns]
#  10  updated_at             19 non-null     datetime64[ns]
# dtypes: category(5), datetime64[ns](2), int64(4)
# memory usage: 2.5 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       19 non-null     int64
#  1   name                     19 non-null     category
#  2   description              19 non-null     category
#  3   is_toxic                 19 non-null     int64
#  4   harvest_duration         19 non-null     int64
#  5   sunlight                 19 non-null     category
#  6   planting_time            19 non-null     category
#  7   plant_category_id        19 non-null     int64
#  8   climate_condition        19 non-null     category
#  9   plant_characteristic_id  19 non-null     int64
#  10  created_at               19 non-null     datetime64[ns]
#  11  updated_at               19 non-null     datetime64[ns]
#  12  additional_tips          19 non-null     category
# dtypes: category(6), datetime64[ns](2), int64(5)
# memory usage: 3.7 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               29 non-null     int64
#  1   user_id          29 non-null     int64
#  2   plant_id         29 non-null     int64
#  3   plant_name       29 non-null     category
#  4   plant_category   29 non-null     category
#  5   plant_image_url  29 non-null     category
#  6   created_at       29 non-null     datetime64[ns]
#  7   updated_at       29 non-null     datetime64[ns]
# dtypes: category(3), datetime64[ns](2), int64(3)
# memory usage: 2.3 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               10 non-null     int64
#  1   user_id          10 non-null     int64
#  2   plant_id         10 non-null     int64
#  3   created_at       10 non-null     datetime64[ns]
#  4   updated_at       10 non-null     datetime64[ns]
#  5   last_watered_at  0 non-null      datetime64[ns]
#  6   customize_name   10 non-null     category
# dtypes: category(1), datetime64[ns](3), int64(3)
# memory usage: 974.0 bytes
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          23 non-null     int64
#  1   name        23 non-null     category
#  2   email       23 non-null     category
#  3   password    23 non-null     category
#  4   is_active   23 non-null     int64
#  5   otp         23 non-null     category
#  6   url_image   23 non-null     category
#  7   created_at  23 non-null     datetime64[ns]
#  8   updated_at  23 non-null     datetime64[ns]
#  9   fcm_token   23 non-null     category
# dtypes: category(6), datetime64[ns](2), int64(2)
# memory usage: 4.6 KB
# None
# Menampilkan Informasi Field di tiap Dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1 non-null      int64
#  1   plant_id    1 non-null      int64
#  2   user_id     1 non-null      int64
#  3   created_at  1 non-null      datetime64[ns]
#  4   updated_at  1 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 168.0 bytes
# None

# %% [markdown]
# ### 3.3.2 Sample Dataframe

# %%
df_watering_histories
# Out:
#    id  plant_id  user_id              created_at              updated_at
# 0   7        62        3 2024-06-18 10:28:04.543 2024-06-18 10:28:04.543

# %% [markdown]
# ## 3.4 Table Fakta &  Dimensional

# %% [markdown]
# ### 3.4.1 Save to CSV Table Dimensional

# %%
dataframes
# Out:
# ['df_admins',
#  'df_customize_watering_reminders',
#  'df_fertilizers',
#  'df_notifications',
#  'df_plant_categories',
#  'df_plant_characteristics',
#  'df_plant_faqs',
#  'df_plant_images',
#  'df_plant_instruction_categories',
#  'df_plant_instructions',
#  'df_plant_progresses',
#  'df_plant_reminders',
#  'df_plants',
#  'df_user_plant_histories',
#  'df_user_plants',
#  'df_users',
#  'df_watering_histories']

# %%
output_dir = "../data_source_dimensional"

for table in tables:
    df_variable_name = f"df_{table}"
    
    csv_filename = os.path.join(output_dir, f"dim_{table}.csv")
    globals()[df_variable_name].to_csv(csv_filename, index=False)
    print(f"Menyimpan Dataframe Dimensional dari dataframe df_{table} ke {csv_filename} \n")
# Out:
# Menyimpan Dataframe Dimensional dari dataframe df_admins ke ../data_source_dimensional/dim_admins.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_customize_watering_reminders ke ../data_source_dimensional/dim_customize_watering_reminders.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_fertilizers ke ../data_source_dimensional/dim_fertilizers.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_notifications ke ../data_source_dimensional/dim_notifications.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_plant_categories ke ../data_source_dimensional/dim_plant_categories.csv
# Menyimpan Dataframe Dimensional dari dataframe df_plant_characteristics ke ../data_source_dimensional/dim_plant_characteristics.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_plant_faqs ke ../data_source_dimensional/dim_plant_faqs.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_plant_images ke ../data_source_dimensional/dim_plant_images.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_plant_instruction_categories ke ../data_source_dimensional/dim_plant_instruction_categories.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_plant_instructions ke ../data_source_dimensional/dim_plant_instructions.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_plant_progresses ke ../data_source_dimensional/dim_plant_progresses.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_plant_reminders ke ../data_source_dimensional/dim_plant_reminders.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_plants ke ../data_source_dimensional/dim_plants.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_user_plant_histories ke ../data_source_dimensional/dim_user_plant_histories.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_user_plants ke ../data_source_dimensional/dim_user_plants.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_users ke ../data_source_dimensional/dim_users.csv
#
# Menyimpan Dataframe Dimensional dari dataframe df_watering_histories ke ../data_source_dimensional/dim_watering_histories.csv

# %% [markdown]
# ### 3.4.2 Dataframe Dimensional

# %%
# Path ke direktori yang berisi file CSV
input_dir = '../data_source_dimensional'

# List untuk menyimpan nama dataframe yang dibuat
dataframe_dimensional = []

# Loop untuk membaca semua file CSV dalam direktori
for filename in os.listdir(input_dir):
    if filename.endswith('.csv'):
        # Mengambil nama tabel dari nama file
        table_name = os.path.splitext(filename)[0]  # Menghilangkan ekstensi .csv
        
        # Membuat nama variabel dataframe
        df_variable_name = f"df_{table_name}"
        
        # Membaca file CSV menjadi dataframe
        df_path = os.path.join(input_dir, filename)
        globals()[df_variable_name] = pd.read_csv(df_path)
        
        # Tambahkan nama dataframe ke dalam list
        dataframe_dimensional.append(df_variable_name)

# Output untuk verifikasi
print(dataframe_dimensional)
# Out:
# ['df_dim_notifications', 'df_dim_user_plant_histories', 'df_dim_plant_categories', 'df_dim_fertilizers', 'df_dim_plant_instructions', 'df_dim_customize_watering_reminders', 'df_dim_watering_histories', 'df_dim_admins', 'df_dim_plant_faqs', 'df_dim_user_plants', 'df_dim_plant_characteristics', 'df_dim_plants', 'df_dim_users', 'df_dim_plant_instruction_categories', 'df_dim_plant_progresses', 'df_dim_plant_reminders', 'df_dim_plant_images']

# %%
dataframe_dimensional
# Out:
# ['df_dim_notifications',
#  'df_dim_user_plant_histories',
#  'df_dim_plant_categories',
#  'df_dim_fertilizers',
#  'df_dim_plant_instructions',
#  'df_dim_customize_watering_reminders',
#  'df_dim_watering_histories',
#  'df_dim_admins',
#  'df_dim_plant_faqs',
#  'df_dim_user_plants',
#  'df_dim_plant_characteristics',
#  'df_dim_plants',
#  'df_dim_users',
#  'df_dim_plant_instruction_categories',
#  'df_dim_plant_progresses',
#  'df_dim_plant_reminders',
#  'df_dim_plant_images']

# %%
for dataframe in dataframe_dimensional:
    df_variable_name = f"{dataframe}"
    
    # Cleansing DataFrame
    globals()[df_variable_name] = cleanse_dataframe(globals()[df_variable_name])
# Out:
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'title'...
# Membersihkan tag HTML di kolom 'body'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'plant_name'...
# Membersihkan tag HTML di kolom 'plant_category'...
# Membersihkan tag HTML di kolom 'plant_image_url'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'image_url'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'id'...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'compostition'...
# Membersihkan tag HTML di kolom 'create_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Memeriksa missing values...
# Mengisi missing values di kolom 'step_title' dengan '-'...
# Mengisi missing values di kolom 'step_image_url' dengan '-'...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'step_title'...
# Membersihkan tag HTML di kolom 'step_description'...
# Membersihkan tag HTML di kolom 'step_image_url'...
# Membersihkan tag HTML di kolom 'additional_tips'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'time'...
# Membersihkan tag HTML di kolom 'type'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Mengisi missing values di kolom 'url_image' dengan 0...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'email'...
# Membersihkan tag HTML di kolom 'password'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'question'...
# Membersihkan tag HTML di kolom 'answer'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/889720400.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna('-', inplace=True)
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/889720400.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(0, inplace=True)
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/889720400.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(0, inplace=True)
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Mengisi missing values di kolom 'last_watered_at' dengan 0...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Membersihkan tag HTML di kolom 'customize_name'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'last_watered_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'height_unit'...
# Membersihkan tag HTML di kolom 'wide_unit'...
# Membersihkan tag HTML di kolom 'leaf_color'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'description'...
# Membersihkan tag HTML di kolom 'sunlight'...
# Membersihkan tag HTML di kolom 'planting_time'...
# Membersihkan tag HTML di kolom 'climate_condition'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Membersihkan tag HTML di kolom 'additional_tips'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Mengisi missing values di kolom 'url_image' dengan 0...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'email'...
# Membersihkan tag HTML di kolom 'password'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Membersihkan tag HTML di kolom 'fcm_token'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name'...
# Membersihkan tag HTML di kolom 'description'...
# Membersihkan tag HTML di kolom 'image_url'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'image_url'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Mengisi missing values di kolom 'condition_description' dengan '-'...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'each'...
# Membersihkan tag HTML di kolom 'unit'...
# Membersihkan tag HTML di kolom 'watering_time'...
# Membersihkan tag HTML di kolom 'weather_condition'...
# Membersihkan tag HTML di kolom 'condition_description'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'file_name'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/889720400.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(0, inplace=True)
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini

# %%
df_dim_plants
# Out:
#     id                               name  \
# 0   61            Rafflesia-Rafflesiaceae
# 1   62                  Tomato-Solanaceae
# 2   63               Lavender - Lamiaceae
# 3   64                  Basil - Lamiaceae
# 4   65              Strawberry - Rosaceae
# 5   66               Rosemary - Lamiaceae
# 6   67             Sunflower - Asteraceae
# 7   68             Peppermint - Lamiaceae
# 8   69                    Rose - Rosaceae
# 9   75           Cucumber - Cucurbitaceae
# 10  76             Geranium - Geraniaceae
# 11  77               Orchid - Orchidaceae
# 12  78                   Lemon - Rutaceae
# 13  79         Mango Tree - Anacardiaceae
# 14  80       Aloe Vera - Xanthorrhoeaceae
# 15  81    Alang alang-Imperata cylindrica
# 16  85                alang alang-Poaceae
# 17  86                    Chili-Capsicum
# 18  87  Alang Alang - Imperata cylindrica
#
#                                           description  is_toxic  \
# 0                                        Bunga Langka         1
# 1   Tomatoes are a warm-season vegetable that grow...         0
# 2   Lavender is a fragrant herb known for its arom...         0
# 3   Basil is a popular herb used in many cuisines ...         0
# 4   Strawberries are perennial plants known for th...         0
# 5   Rosemary is an aromatic herb with needle-like ...         0
# 6   Sunflowers are tall flowering plants with larg...         0
# 7   Peppermint is a hybrid mint known for its stro...         0
# 8   Roses are ornamental flowering plants known fo...         0
# 9   Cucumbers are climbing plants known for their ...         0
# 10  Geraniums are flowering plants known for their...         0
# 0                                    Tipsnya ya gituu
# 1   Support plants with stakes or cages to prevent...
# 2   Mulch around plants to retain moisture and con...
# 3   Regularly pinch off flower buds to prolong the...
# 4   Provide good air circulation to prevent fungal...
# 5   Protect from frost in colder climates or bring...
# 6   Deadhead spent flowers to encourage continuous...
# 7   Divide peppermint plants every 2-3 years to pr...
# 8   Mulch around roses to retain moisture and supp...
# 9   Provide support for climbing plants, such as w...
# 10  Provide afternoon shade during hot summer mont...
# 11  Provide adequate air circulation around orchid...
# 12  Protect young lemon trees from frost by coveri...
# 13  Protect young mango trees from frost by coveri...
# 14  Aloe Vera thrives indoors near a sunny window ...
# 15                      itu tumbuhan liar, biarin aja
# 16  biarkan saja karena akan tumbuh dengan sendirinya
# 17  Planting chili peppers (capsicum) successfully...
# 18  Alang-alang thrives in full sunlight but can t...

# %% [markdown]
# ### 3.4.3 Merged to Fact Table User Activities

# %% [markdown]
# #### 3.4.3.1 Merged dim_my_plants

# %%
df_dim_users.rename(columns={'id': 'user_id'}, inplace=True)
df_dim_users.rename(columns={'name': 'user_name'}, inplace=True)
df_dim_users
# Out:
#     user_id                          user_name  \
# 0         3  Octaviano Ryan Eka Putra Hartanto
# 1         5                          Setiabudi
# 2         6                        Aletha Safa
# 3         7                     Valdimir Putin
# 4         9                        Aletha Safa
# 5        10                        Aletha Safa
# 6        11                        Aletha Safa
# 7        12                        Aletha Safa
# 8        14                        Dafa Aldian
# 9        15                             Annisa
# 10       16                             Annisa
# 11       17                             annisa
# 12       18                            rizkyyy
# 13       19                              rizky
# 14       20                              rizky
# 15       21                          developer
# 16       22                             salkia
# 17       23                             farhan
# 18       24                             salkia
# 19       25  Octaviano Ryan Eka Putra Hartanto
# 20       26  Octaviano Ryan Eka Putra Hartanto
# 21       27                          dumy akun
# 22       28                          dumy akun
#
#                                email  \
# 0         octavianoryan030@gmail.com
# 1   mamansetiabudi12061982@gmail.com
# 2               yellowblue@gmail.com
# 3           kangkingkung79@gmail.com
# 4                  yellow3@gmail.com
# 5                   blue04@gmail.com
# 6                   blue05@gmail.com
# 7                   blue06@gmail.com
# 8            dafaaldian155@gmail.com
# 9                   annisa@gmail.com
# 10        nuranisaseptriza@gmail.com
# 11              cachakim60@gmail.com
# 12        rizkynugroho2901@gmail.com
# 13            not1ntrovert@gmail.com
# 14         not1ntrovertfps@gmail.com
# 15           gamerproind20@gmail.com
# 16        Salkiaagustien13@gmail.com
# 17                 zuwiy10@gmail.com
# 18          agustiensalkia@gmail.com
# 19   octavianoryan25102003@gmail.com
# 20         octavianoryan25@gmail.com
# 21              dumyakun97@gmail.com
# 22              dumyakun69@gmail.com
#
#                                              password  is_active     otp  \
# 0   $2a$08$R9/7B15r6CgnfHhTEvW3o.qDQtB61Vmw2WxL8OQ...          1  986482
# 1   $2a$08$ur/09YUT0MI2s5CvTcKNWOz29g73ZbaIaa7mdti...          1  364170
# 2   $2a$08$kRWcnKu27ojUmST7WqB17.OZYKI1En2MYHFVtMg...          0  486315
# 3   $2a$08$8TlhkfNRNocMnI1RAs1gXuQXZomO1ILgP8vQVbn...          1  714585
# 13  dH_c2I-PSiilsZsWbIqsvV:APA91bE4CJyKvFYT7XJ1pxb...
# 14  dH_c2I-PSiilsZsWbIqsvV:APA91bHYcZEhXgk-SJZQ-w0...
# 15  dH_c2I-PSiilsZsWbIqsvV:APA91bFSrvn1Ok1eYpAVUlp...
# 16  enYsCpA4SyCfztWDhjcv1g:APA91bFDdtlOp9MifpsiTrc...
# 17  dF9WdTr0QmmIPpYVbxLjZJ:APA91bECbPFLP9dFrsoDLH7...
# 18  enYsCpA4SyCfztWDhjcv1g:APA91bG4ox9yyUzwYPn5-dc...
# 19  dF9WdTr0QmmIPpYVbxLjZJ:APA91bECbPFLP9dFrsoDLH7...
# 20  dH_c2I-PSiilsZsWbIqsvV:APA91bFSrvn1Ok1eYpAVUlp...
# 21  fGlstT-gQ0O4svve3G3iBZ:APA91bGWezWesVpmQ5kv9m-...
# 22  fGlstT-gQ0O4svve3G3iBZ:APA91bFyg33gkyND-oBOpYL...

# %%
df_dim_plants.rename(columns={'id': 'plant_id'}, inplace=True)
df_dim_plants.rename(columns={'name': 'plant_name'}, inplace=True)
df_dim_plants
# Out:
#     plant_id                         plant_name  \
# 0         61            Rafflesia-Rafflesiaceae
# 1         62                  Tomato-Solanaceae
# 2         63               Lavender - Lamiaceae
# 3         64                  Basil - Lamiaceae
# 4         65              Strawberry - Rosaceae
# 5         66               Rosemary - Lamiaceae
# 6         67             Sunflower - Asteraceae
# 7         68             Peppermint - Lamiaceae
# 8         69                    Rose - Rosaceae
# 9         75           Cucumber - Cucurbitaceae
# 10        76             Geranium - Geraniaceae
# 11        77               Orchid - Orchidaceae
# 12        78                   Lemon - Rutaceae
# 13        79         Mango Tree - Anacardiaceae
# 14        80       Aloe Vera - Xanthorrhoeaceae
# 15        81    Alang alang-Imperata cylindrica
# 16        85                alang alang-Poaceae
# 17        86                    Chili-Capsicum
# 18        87  Alang Alang - Imperata cylindrica
#
#                                           description  is_toxic  \
# 0                                        Bunga Langka         1
# 1   Tomatoes are a warm-season vegetable that grow...         0
# 2   Lavender is a fragrant herb known for its arom...         0
# 3   Basil is a popular herb used in many cuisines ...         0
# 4   Strawberries are perennial plants known for th...         0
# 5   Rosemary is an aromatic herb with needle-like ...         0
# 6   Sunflowers are tall flowering plants with larg...         0
# 7   Peppermint is a hybrid mint known for its stro...         0
# 8   Roses are ornamental flowering plants known fo...         0
# 9   Cucumbers are climbing plants known for their ...         0
# 10  Geraniums are flowering plants known for their...         0
# 11  Orchids are exotic flowering plants known for ...         0
# 12  Lemon trees are citrus plants known for their ...         0
# 13  Mango trees are tropical fruit trees known for...         0
# 14  Aloe Vera is a succulent plant known for its m...         0
# 15                              Anggap aja Rumput lah         0
# 16  Alang-alang adalah rumput perennial yang serin...         0
# 17  "Cabe" is a term that typically refers to chil...         0
# 18  Alang-alang adalah rumput perennial yang serin...         0
#
#     harvest_duration sunlight planting_time  plant_category_id  \
# 0                  6  Partsun        Autumn                 11
# 1                  3  Fullsun        Spring                  1
# 13  Protect young mango trees from frost by coveri...
# 14  Aloe Vera thrives indoors near a sunny window ...
# 15                      itu tumbuhan liar, biarin aja
# 16  biarkan saja karena akan tumbuh dengan sendirinya
# 17  Planting chili peppers (capsicum) successfully...
# 18  Alang-alang thrives in full sunlight but can t...

# %%
df_dim_user_plants
# Out:
#     id  user_id  plant_id                 created_at  \
# 0  137        3        62 2024-06-18 19:18:43.425460
# 1  149       17        62 2024-06-18 19:18:43.425460
# 2  150       14        75 2024-06-18 19:18:43.425460
# 3  151       23        61 2024-06-18 19:18:43.425460
# 4  152       14        62 2024-06-18 19:18:43.425460
# 5  153       14        61 2024-06-18 19:18:43.425460
# 6  154       14        63 2024-06-18 19:18:43.425460
# 7  155       14        64 2024-06-18 19:18:43.425460
# 8  156       14        65 2024-06-18 19:18:43.425460
# 9  157       28        61 2024-06-18 19:18:43.425460
#
#                   updated_at last_watered_at            customize_name
# 0 2024-06-18 19:18:43.429529             NaT                         -
# 1 2024-06-18 19:18:43.429529             NaT         Tomato-Solanaceae
# 2 2024-06-18 19:18:43.429529             NaT  Cucumber - Cucurbitaceae
# 3 2024-06-18 19:18:43.429529             NaT   Rafflesia-Rafflesiaceae
# 4 2024-06-18 19:18:43.429529             NaT         Tomato-Solanaceae
# 5 2024-06-18 19:18:43.429529             NaT   Rafflesia-Rafflesiaceae
# 6 2024-06-18 19:18:43.429529             NaT      Lavender - Lamiaceae
# 7 2024-06-18 19:18:43.429529             NaT         Basil - Lamiaceae
# 8 2024-06-18 19:18:43.429529             NaT     Strawberry - Rosaceae
# 9 2024-06-18 19:18:43.429529             NaT   Rafflesia-Rafflesiaceae

# %%
# Melakukan merge dalam satu baris kode dengan suffixes untuk menghindari konflik kolom
df_dim_my_plants = df_user_plants.merge(df_dim_users, on='user_id', how='left', suffixes=('', '_user'))

# Memeriksa nama kolom setelah merge
print(df_dim_my_plants.columns)
# Out:
# Index(['id', 'user_id', 'plant_id', 'created_at', 'updated_at',
#        'last_watered_at', 'customize_name', 'user_name', 'email', 'password',
#        'is_active', 'otp', 'url_image', 'created_at_user', 'updated_at_user',
#        'fcm_token'],
#       dtype='object')

# %%
# Melakukan merge dalam satu baris kode dengan suffixes untuk menghindari konflik kolom
df_dim_my_plants = df_dim_my_plants.merge(df_dim_plants, on='plant_id', how='left', suffixes=('', '_plant'))

# Memeriksa nama kolom setelah merge
print(df_dim_my_plants.columns)
# Out:
# Index(['id', 'user_id', 'plant_id', 'created_at', 'updated_at',
#        'last_watered_at', 'customize_name', 'user_name', 'email', 'password',
#        'is_active', 'otp', 'url_image', 'created_at_user', 'updated_at_user',
#        'fcm_token', 'plant_name', 'description', 'is_toxic',
#        'harvest_duration', 'sunlight', 'planting_time', 'plant_category_id',
#        'climate_condition', 'plant_characteristic_id', 'created_at_plant',
#        'updated_at_plant', 'additional_tips'],
#       dtype='object')

# %%
# Memilih kolom yang diinginkan
df_dim_my_plants = df_dim_my_plants[['id', 'user_name', 'plant_name', 'created_at', 'updated_at', 'last_watered_at']]
df_dim_my_plants
# Out:
#     id                          user_name                plant_name  \
# 0  137  Octaviano Ryan Eka Putra Hartanto         Tomato-Solanaceae
# 1  149                             annisa         Tomato-Solanaceae
# 2  150                        Dafa Aldian  Cucumber - Cucurbitaceae
# 3  151                             farhan   Rafflesia-Rafflesiaceae
# 4  152                        Dafa Aldian         Tomato-Solanaceae
# 5  153                        Dafa Aldian   Rafflesia-Rafflesiaceae
# 6  154                        Dafa Aldian      Lavender - Lamiaceae
# 7  155                        Dafa Aldian         Basil - Lamiaceae
# 8  156                        Dafa Aldian     Strawberry - Rosaceae
# 9  157                          dumy akun   Rafflesia-Rafflesiaceae
#
#                created_at              updated_at last_watered_at
# 0 2024-06-17 00:00:00.000 2024-06-17 00:00:00.000             NaT
# 1 2024-06-18 04:30:35.996 2024-06-18 04:30:35.996             NaT
# 2 2024-06-18 06:23:25.398 2024-06-18 06:23:25.398             NaT
# 3 2024-06-18 06:23:52.937 2024-06-18 06:23:52.937             NaT
# 4 2024-06-18 07:15:09.863 2024-06-18 07:15:09.863             NaT
# 5 2024-06-18 07:15:20.779 2024-06-18 07:15:20.779             NaT
# 6 2024-06-18 07:15:25.812 2024-06-18 07:15:25.812             NaT
# 7 2024-06-18 07:15:31.449 2024-06-18 07:15:31.449             NaT
# 8 2024-06-18 07:15:44.372 2024-06-18 07:15:44.372             NaT
# 9 2024-06-18 09:40:27.099 2024-06-18 09:40:27.099             NaT

# %%
df_dim_my_plants.rename(columns={'id': 'my_plant_id'}, inplace=True)

# %%
df_dim_my_plants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   my_plant_id      10 non-null     int64
#  1   user_name        10 non-null     category
#  2   plant_name       10 non-null     category
#  3   created_at       10 non-null     datetime64[ns]
#  4   updated_at       10 non-null     datetime64[ns]
#  5   last_watered_at  0 non-null      datetime64[ns]
# dtypes: category(2), datetime64[ns](3), int64(1)
# memory usage: 1.8 KB

# %% [markdown]
# ##### a. Save to CSV

# %%
df_dim_my_plants.to_csv('../data_source_to_load/dim_my_plants.csv', index=False)

# %% [markdown]
# #### 3.4.3.2 Merged dim_planting_histories

# %%
# Melakukan merge dalam satu baris kode dengan suffixes untuk menghindari konflik kolom
df_dim_user_plant_histories = df_dim_user_plant_histories.merge(
    df_dim_users, on='user_id', how='left', suffixes=('', '_user'))

# Memeriksa nama kolom setelah merge
print(df_dim_user_plant_histories.columns)
# Out:
# Index(['id', 'user_id', 'plant_id', 'plant_name', 'plant_category',
#        'plant_image_url', 'created_at', 'updated_at', 'user_name', 'email',
#        'password', 'is_active', 'otp', 'url_image', 'created_at_user',
#        'updated_at_user', 'fcm_token'],
#       dtype='object')

# %%
# Memilih kolom yang diinginkan
df_dim_user_plant_histories = df_dim_user_plant_histories[['id', 'user_name', 'plant_name', 'plant_category', 'created_at', 'updated_at']]
df_dim_user_plant_histories.rename(columns={'id': 'planting_history_id'}, inplace=True)
df_dim_user_plant_histories
# Out:
#     planting_history_id                          user_name  \
# 0                     2  Octaviano Ryan Eka Putra Hartanto
# 1                     3                        Dafa Aldian
# 2                     4                        Dafa Aldian
# 3                     5                        Dafa Aldian
# 4                     6                        Dafa Aldian
# 5                     7                        Dafa Aldian
# 6                     8                        Dafa Aldian
# 7                     9                        Dafa Aldian
# 8                    10                        Dafa Aldian
# 9                    11                        Dafa Aldian
# 10                   12                        Dafa Aldian
# 11                   13                        Dafa Aldian
# 21 2024-06-18 19:18:43.249725
# 22 2024-06-18 19:18:43.249725
# 23 2024-06-18 19:18:43.249725
# 24 2024-06-18 19:18:43.249725
# 25 2024-06-18 19:18:43.249725
# 26 2024-06-18 19:18:43.249725
# 27 2024-06-18 19:18:43.249725
# 28 2024-06-18 19:18:43.249725

# %% [markdown]
# ##### a. Save to CSV

# %%
df_dim_user_plant_histories.to_csv('../data_source_to_load/dim_planting_histories.csv', index=False)

# %% [markdown]
# #### 3.4.3.3 Merged dim_watering_histories

# %%
# Melakukan merge dalam satu baris kode dengan suffixes untuk menghindari konflik kolom
df_dim_watering_histories = df_watering_histories.merge(df_dim_users, on='user_id', how='left', suffixes=('', '_user')).merge(
    df_dim_plants, on='plant_id', how='left', suffixes=('', '_plant'))

df_dim_watering_histories = df_dim_watering_histories[['id', 'user_name', 'plant_name', 'created_at', 'updated_at']]
df_dim_watering_histories.rename(columns={'id': 'watering_history_id'}, inplace=True)
df_dim_watering_histories
# Out:
#    watering_history_id                          user_name         plant_name  \
# 0                    7  Octaviano Ryan Eka Putra Hartanto  Tomato-Solanaceae
#
#                created_at              updated_at
# 0 2024-06-18 10:28:04.543 2024-06-18 10:28:04.543

# %% [markdown]
# ##### a. Save to CSV

# %%
df_dim_watering_histories.to_csv('../data_source_to_load/dim_watering_histories.csv', index=False)

# %% [markdown]
# #### 3.4.3.4 dim_customize_watering_reminders

# %%
df_dim_customize_watering_reminders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2 non-null      int64
#  1   my_plant_id  2 non-null      int64
#  2   time         2 non-null      category
#  3   recurring    2 non-null      int64
#  4   type         2 non-null      category
#  5   created_at   2 non-null      datetime64[ns]
#  6   updated_at   2 non-null      datetime64[ns]
# dtypes: category(2), datetime64[ns](2), int64(3)
# memory usage: 444.0 bytes

# %%
df_dim_customize_watering_reminders.rename(columns={'id': 'customize_watering_reminder_id'}, inplace=True)
df_dim_customize_watering_reminders
# Out:
#    customize_watering_reminder_id  my_plant_id   time  recurring   type  \
# 0                               8          137  17:00          1  daily
# 1                               9          153  17:00          1  daily
#
#                   created_at                 updated_at
# 0 2024-06-18 19:18:43.330886 2024-06-18 19:18:43.331500
# 1 2024-06-18 19:18:43.330886 2024-06-18 19:18:43.331500

# %% [markdown]
# ##### a. Save to CSV

# %%
df_dim_customize_watering_reminders.to_csv('../data_source_to_load/dim_customize_watering_reminders.csv', index=False)

# %% [markdown]
# #### 3.4.3.5 Merged Final Fact Table User Activities

# %%
# Menggabungkan keseluruhan id dataframe kedalam Fact User Activites
df_fact_user_activities = pd.merge(df_dim_my_plants, df_dim_user_plant_histories,
                                   on=["user_name", "plant_name"], how='outer',
                                   suffixes=('_my_plants', '_planting'))

df_fact_user_activities = pd.merge(df_fact_user_activities, df_dim_watering_histories,
                                   on=["user_name", "plant_name"], how='outer',
                                   suffixes=('_fact', '_watering'))

df_fact_user_activities = df_fact_user_activities[['my_plant_id', 'planting_history_id', 'watering_history_id']]
df_fact_user_activities
# Out:
#     my_plant_id  planting_history_id  watering_history_id
# 0         155.0                 27.0                  NaN
# 1         150.0                 22.0                  NaN
# 2         154.0                 26.0                  NaN
# 3         153.0                 25.0                  NaN
# 4           NaN                  3.0                  NaN
# 5           NaN                  6.0                  NaN
# 6           NaN                  9.0                  NaN
# 7           NaN                 11.0                  NaN
# 8           NaN                 13.0                  NaN
# 9           NaN                 14.0                  NaN
# 10          NaN                 19.0                  NaN
# 11        156.0                 28.0                  NaN
# 12        152.0                 24.0                  NaN
# 13          NaN                  8.0                  NaN
# 14          NaN                 15.0                  NaN
# 15          NaN                  4.0                  NaN
# 16          NaN                  5.0                  NaN
# 17          NaN                  7.0                  NaN
# 18          NaN                 10.0                  NaN
# 19          NaN                 12.0                  NaN
# 20          NaN                 16.0                  NaN
# 21          NaN                  2.0                  NaN
# 22        137.0                  NaN                  7.0
# 23        149.0                  NaN                  NaN
# 24          NaN                 30.0                  NaN
# 25          NaN                 20.0                  NaN
# 26          NaN                 21.0                  NaN
# 27        157.0                 29.0                  NaN
# 28        151.0                 23.0                  NaN
# 29          NaN                 17.0                  NaN
# 30          NaN                 18.0                  NaN

# %%
df_fact_user_activities['watering_count'] = df_fact_user_activities['watering_history_id'].nunique()
df_fact_user_activities['planting_count'] = df_fact_user_activities['planting_history_id'].nunique()
df_fact_user_activities['user_plant_count'] = df_fact_user_activities['my_plant_id'].nunique()
df_fact_user_activities
# Out:
#     my_plant_id  planting_history_id  watering_history_id  watering_count  \
# 0         155.0                 27.0                  NaN               1
# 1         150.0                 22.0                  NaN               1
# 2         154.0                 26.0                  NaN               1
# 3         153.0                 25.0                  NaN               1
# 4           NaN                  3.0                  NaN               1
# 5           NaN                  6.0                  NaN               1
# 6           NaN                  9.0                  NaN               1
# 7           NaN                 11.0                  NaN               1
# 8           NaN                 13.0                  NaN               1
# 9           NaN                 14.0                  NaN               1
# 10          NaN                 19.0                  NaN               1
# 11        156.0                 28.0                  NaN               1
# 12        152.0                 24.0                  NaN               1
# 13          NaN                  8.0                  NaN               1
# 14          NaN                 15.0                  NaN               1
# 15          NaN                  4.0                  NaN               1
# 16          NaN                  5.0                  NaN               1
# 17          NaN                  7.0                  NaN               1
# 18          NaN                 10.0                  NaN               1
# 19          NaN                 12.0                  NaN               1
# 20          NaN                 16.0                  NaN               1
# 21          NaN                  2.0                  NaN               1
# 22        137.0                  NaN                  7.0               1
# 23        149.0                  NaN                  NaN               1
# 24          NaN                 30.0                  NaN               1
# 25          NaN                 20.0                  NaN               1
# 26          NaN                 21.0                  NaN               1
# 27        157.0                 29.0                  NaN               1
# 28        151.0                 23.0                  NaN               1
# 29          NaN                 17.0                  NaN               1
# 30          NaN                 18.0                  NaN               1
#
#     planting_count  user_plant_count
# 0               29                10
# 1               29                10
# 2               29                10
# 3               29                10
# 4               29                10
# 5               29                10
# 6               29                10
# 7               29                10
# 8               29                10
# 9               29                10
# 10              29                10
# 11              29                10
# 12              29                10
# 13              29                10
# 14              29                10
# 15              29                10
# 16              29                10
# 17              29                10
# 18              29                10
# 19              29                10
# 20              29                10
# 21              29                10
# 22              29                10
# 23              29                10
# 24              29                10
# 25              29                10
# 26              29                10
# 27              29                10
# 28              29                10
# 29              29                10
# 30              29                10

# %% [markdown]
# #### a. Change Type Data

# %%
cleanse_dataframe_fact(df_fact_user_activities)
change_type_data(df_fact_user_activities)
df_fact_user_activities
# Out:
# Memeriksa missing values...
# Mengisi missing values di kolom 'my_plant_id' dengan -1...
# Mengisi missing values di kolom 'planting_history_id' dengan -1...
# Mengisi missing values di kolom 'watering_history_id' dengan -1...
# Memastikan tipe data yang benar...
# /tmp/ipykernel_70970/3818586073.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(-1, inplace=True)
#     my_plant_id  planting_history_id  watering_history_id  watering_count  \
# 0           155                   27                   -1               1
# 1           150                   22                   -1               1
# 2           154                   26                   -1               1
# 3           153                   25                   -1               1
# 4            -1                    3                   -1               1
# 5            -1                    6                   -1               1
# 6            -1                    9                   -1               1
# 7            -1                   11                   -1               1
# 8            -1                   13                   -1               1
# 9            -1                   14                   -1               1
# 10           -1                   19                   -1               1
# 11          156                   28                   -1               1
# 12          152                   24                   -1               1
# 13           -1                    8                   -1               1
# 14           -1                   15                   -1               1
# 15           -1                    4                   -1               1
# 16           -1                    5                   -1               1
# 17           -1                    7                   -1               1
# 18           -1                   10                   -1               1
# 19           -1                   12                   -1               1
# 20           -1                   16                   -1               1
# 21           -1                    2                   -1               1
# 22          137                   -1                    7               1
# 23          149                   -1                   -1               1
# 24           -1                   30                   -1               1
# 25           -1                   20                   -1               1
# 26           -1                   21                   -1               1
# 27          157                   29                   -1               1
# 28          151                   23                   -1               1
# 29           -1                   17                   -1               1
# 30           -1                   18                   -1               1
#
#     planting_count  user_plant_count
# 0               29                10
# 1               29                10
# 2               29                10
# 3               29                10
# 4               29                10
# 5               29                10
# 6               29                10
# 7               29                10
# 8               29                10
# 9               29                10
# 10              29                10
# 11              29                10
# 12              29                10
# 13              29                10
# 14              29                10
# 15              29                10
# 16              29                10
# 17              29                10
# 18              29                10
# 19              29                10
# 20              29                10
# 21              29                10
# 22              29                10
# 23              29                10
# 24              29                10
# 25              29                10
# 26              29                10
# 27              29                10
# 28              29                10
# 29              29                10
# 30              29                10

# %% [markdown]
# ##### b. Save to CSV

# %%
df_fact_user_activities.to_csv('../data_source_to_load/fact_user_activities.csv', index=False)

# %% [markdown]
# ### 3.4.4 Merged to Fact Table Plants Data

# %% [markdown]
# #### 3.4.4.1 Merged dim_plants

# %%
df_dim_plants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   plant_id                 19 non-null     int64
#  1   plant_name               19 non-null     category
#  2   description              19 non-null     category
#  3   is_toxic                 19 non-null     int64
#  4   harvest_duration         19 non-null     int64
#  5   sunlight                 19 non-null     category
#  6   planting_time            19 non-null     category
#  7   plant_category_id        19 non-null     int64
#  8   climate_condition        19 non-null     category
#  9   plant_characteristic_id  19 non-null     int64
#  10  created_at               19 non-null     datetime64[ns]
#  11  updated_at               19 non-null     datetime64[ns]
#  12  additional_tips          19 non-null     category
# dtypes: category(6), datetime64[ns](2), int64(5)
# memory usage: 3.7 KB

# %%
df_dim_plants
# Out:
#     plant_id                         plant_name  \
# 0         61            Rafflesia-Rafflesiaceae
# 1         62                  Tomato-Solanaceae
# 2         63               Lavender - Lamiaceae
# 3         64                  Basil - Lamiaceae
# 4         65              Strawberry - Rosaceae
# 5         66               Rosemary - Lamiaceae
# 6         67             Sunflower - Asteraceae
# 7         68             Peppermint - Lamiaceae
# 8         69                    Rose - Rosaceae
# 9         75           Cucumber - Cucurbitaceae
# 10        76             Geranium - Geraniaceae
# 11        77               Orchid - Orchidaceae
# 12        78                   Lemon - Rutaceae
# 13        79         Mango Tree - Anacardiaceae
# 14        80       Aloe Vera - Xanthorrhoeaceae
# 15        81    Alang alang-Imperata cylindrica
# 16        85                alang alang-Poaceae
# 17        86                    Chili-Capsicum
# 18        87  Alang Alang - Imperata cylindrica
#
#                                           description  is_toxic  \
# 0                                        Bunga Langka         1
# 1   Tomatoes are a warm-season vegetable that grow...         0
# 2   Lavender is a fragrant herb known for its arom...         0
# 3   Basil is a popular herb used in many cuisines ...         0
# 4   Strawberries are perennial plants known for th...         0
# 5   Rosemary is an aromatic herb with needle-like ...         0
# 6   Sunflowers are tall flowering plants with larg...         0
# 7   Peppermint is a hybrid mint known for its stro...         0
# 8   Roses are ornamental flowering plants known fo...         0
# 9   Cucumbers are climbing plants known for their ...         0
# 10  Geraniums are flowering plants known for their...         0
# 11  Orchids are exotic flowering plants known for ...         0
# 12  Lemon trees are citrus plants known for their ...         0
# 13  Mango trees are tropical fruit trees known for...         0
# 14  Aloe Vera is a succulent plant known for its m...         0
# 15                              Anggap aja Rumput lah         0
# 16  Alang-alang adalah rumput perennial yang serin...         0
# 17  "Cabe" is a term that typically refers to chil...         0
# 18  Alang-alang adalah rumput perennial yang serin...         0
#
#     harvest_duration sunlight planting_time  plant_category_id  \
# 0                  6  Partsun        Autumn                 11
# 1                  3  Fullsun        Spring                  1
# 2                  6  Fullsun        Summer                  7
# 3                  1  Partsun        Spring                  5
# 4                  3    Shade        Spring                  1
# 5                  1  Fullsun        Spring                  5
# 6                  3  Fullsun        Spring                 12
# 7                  3  Partsun        Spring                  5
# 8                  6  Fullsun        Spring                  7
# 9                  3  Fullsun        Spring                  1
# 10                 3  Partsun        Spring                 15
# 11                 3    Shade        Spring                 15
# 12                 9  Fullsun        Spring                  1
# 13                12  Fullsun        Spring                  1
# 14                12  Fullsun        Summer                  2
# 15                 1  Fullsun        Summer                 15
# 16                 1  Fullsun        Summer                 15
# 17                 1  Partsun        Summer                  1
# 18                 1  Fullsun        Summer                 15
#
#    climate_condition  plant_characteristic_id                 created_at  \
# 0                Wet                        0 2024-06-18 19:18:43.466929
# 1                Dry                        0 2024-06-18 19:18:43.466929
# 2                Dry                        0 2024-06-18 19:18:43.466929
# 3                Wet                        0 2024-06-18 19:18:43.466929
# 4                Dry                        0 2024-06-18 19:18:43.466929
# 5                Dry                        0 2024-06-18 19:18:43.466929
# 6                Dry                        0 2024-06-18 19:18:43.466929
# 7                Wet                        0 2024-06-18 19:18:43.466929
# 8                Wet                        0 2024-06-18 19:18:43.466929
# 9                Wet                        0 2024-06-18 19:18:43.466929
# 10               Wet                        0 2024-06-18 19:18:43.466929
# 11               Dry                        0 2024-06-18 19:18:43.466929
# %%
# Melakukan merge dalam satu baris kode dengan suffixes untuk menghindari konflik kolom
df_dim_plants = df_dim_plants.merge(
    df_dim_plant_categories, on='plant_category_id', how='left', suffixes=('', '_category'))

# Memeriksa nama kolom setelah merge
print(df_dim_plants.columns)
# Out:
# Index(['plant_id', 'plant_name', 'description', 'is_toxic', 'harvest_duration',
#        'sunlight', 'planting_time', 'plant_category_id', 'climate_condition',
#        'plant_characteristic_id', 'created_at', 'updated_at',
#        'additional_tips', 'plant_category', 'image_url', 'created_at_category',
#        'updated_at_category'],
#       dtype='object')

# %%
df_dim_plants = df_dim_plants[['plant_id', 'plant_name', 'description', 'is_toxic', 'harvest_duration',
                            'sunlight', 'planting_time', 'plant_category', 'climate_condition',
                            'additional_tips', 'created_at', 'updated_at']]
df_dim_plants
# Out:
#     plant_id                         plant_name  \
# 0         61            Rafflesia-Rafflesiaceae
# 1         62                  Tomato-Solanaceae
# 2         63               Lavender - Lamiaceae
# 3         64                  Basil - Lamiaceae
# 4         65              Strawberry - Rosaceae
# 5         66               Rosemary - Lamiaceae
# 6         67             Sunflower - Asteraceae
# 7         68             Peppermint - Lamiaceae
# 8         69                    Rose - Rosaceae
# 9         75           Cucumber - Cucurbitaceae
# 10        76             Geranium - Geraniaceae
# 11        77               Orchid - Orchidaceae
# 12        78                   Lemon - Rutaceae
# 13        79         Mango Tree - Anacardiaceae
# 14        80       Aloe Vera - Xanthorrhoeaceae
# 15        81    Alang alang-Imperata cylindrica
# 16        85                alang alang-Poaceae
# 17        86                    Chili-Capsicum
# 18        87  Alang Alang - Imperata cylindrica
#
#                                           description  is_toxic  \
# 0                                        Bunga Langka         1
# 1   Tomatoes are a warm-season vegetable that grow...         0
# 2   Lavender is a fragrant herb known for its arom...         0
# 3   Basil is a popular herb used in many cuisines ...         0
# 4   Strawberries are perennial plants known for th...         0
# 5   Rosemary is an aromatic herb with needle-like ...         0
# 6   Sunflowers are tall flowering plants with larg...         0
# 7   Peppermint is a hybrid mint known for its stro...         0
# 8   Roses are ornamental flowering plants known fo...         0
# 9   Cucumbers are climbing plants known for their ...         0
# 10  Geraniums are flowering plants known for their...         0
# 11  Orchids are exotic flowering plants known for ...         0
# 12  Lemon trees are citrus plants known for their ...         0
# 13  Mango trees are tropical fruit trees known for...         0
# 14  Aloe Vera is a succulent plant known for its m...         0
# 15                              Anggap aja Rumput lah         0
# 16  Alang-alang adalah rumput perennial yang serin...         0
# 17  "Cabe" is a term that typically refers to chil...         0
# 18  Alang-alang adalah rumput perennial yang serin...         0
#
#     harvest_duration sunlight planting_time plant_category climate_condition  \
# 0                  6  Partsun        Autumn       Conifers               Wet
# 1                  3  Fullsun        Spring         Fruits               Dry
# 2                  6  Fullsun        Summer         Shrubs               Dry
# 3                  1  Partsun        Spring          Herbs               Wet
# 4                  3    Shade        Spring         Fruits               Dry
# 5                  1  Fullsun        Spring          Herbs               Dry
# 6                  3  Fullsun        Spring         Annual               Dry
# 7                  3  Partsun        Spring          Herbs               Wet
# 8                  6  Fullsun        Spring         Shrubs               Wet
# 9                  3  Fullsun        Spring         Fruits               Wet
# 10                 3  Partsun        Spring     Perennials               Wet
# 11                 3    Shade        Spring     Perennials               Dry
# 12                 9  Fullsun        Spring         Fruits               Dry
# 13                12  Fullsun        Spring         Fruits               Dry
# 14                12  Fullsun        Summer     Succulents               Dry
# 15                 1  Fullsun        Summer     Perennials               Dry
# 16                 1  Fullsun        Summer     Perennials               Dry
# 17                 1  Partsun        Summer         Fruits               Dry
# 18                 1  Fullsun        Summer     Perennials               Dry
#
#                                       additional_tips  \
# 0                                    Tipsnya ya gituu
# 1   Support plants with stakes or cages to prevent...
# 2   Mulch around plants to retain moisture and con...
# 3   Regularly pinch off flower buds to prolong the...
# 4   Provide good air circulation to prevent fungal...
# 5   Protect from frost in colder climates or bring...
# 6   Deadhead spent flowers to encourage continuous...
# 7   Divide peppermint plants every 2-3 years to pr...
# 8   Mulch around roses to retain moisture and supp...
# 9   Provide support for climbing plants, such as w...
# 10  Provide afternoon shade during hot summer mont...
# 11  Provide adequate air circulation around orchid...
# 12  Protect young lemon trees from frost by coveri...
# 13  Protect young mango trees from frost by coveri...
# 14  Aloe Vera thrives indoors near a sunny window ...
# 15                      itu tumbuhan liar, biarin aja
# 16  biarkan saja karena akan tumbuh dengan sendirinya
# 17  Planting chili peppers (capsicum) successfully...
# 18  Alang-alang thrives in full sunlight but can t...
#
#                    created_at                 updated_at
# 0  2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 1  2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 2  2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 3  2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 4  2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 5  2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 6  2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 7  2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 8  2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 9  2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 10 2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 11 2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 12 2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 13 2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 14 2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 15 2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 16 2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 17 2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420
# 18 2024-06-18 19:18:43.466929 2024-06-18 19:18:43.468420

# %% [markdown]
# ##### a. Save to CSV

# %%
df_dim_plants.to_csv('../data_source_to_load/dim_plants.csv', index=False)

# %% [markdown]
# #### 3.4.4.2 dim_watering_reminders

# %%
df_dim_plant_reminders = df_dim_plant_reminders[['id', 'plant_id', 'watering_frequency', 'each', 'watering_amount',
       'unit', 'watering_time', 'weather_condition', 'condition_description',
       'created_at', 'updated_at']]
df_dim_plant_reminders
# Out:
#     id  plant_id  watering_frequency  each  watering_amount             unit  \
# 0   61        61                   5  Week              300        Liter (l)
# 1   62        62                   3  Week                2        Liter (l)
# 2   63        63                   1  Week                1        Liter (l)
# 3   64        64                   4  Week              500  Milliliter (ml)
# 4   65        65                   2  Week                1        Liter (l)
# 5   66        66                   1  Week              500  Milliliter (ml)
# 6   67        67                   2  Week                1        Liter (l)
# 7   68        68                   2  Week              500  Milliliter (ml)
# 8   69        69                   2  Week                2        Liter (l)
# 9   75        75                   3  Week                1        Liter (l)
# 10  76        76                   1  Week              500  Milliliter (ml)
# 11  77        77                   1  Week              500        Liter (l)
# 12  78        78                   1  Week                5        Liter (l)
# 13  79        79                   1  Week               10        Liter (l)
# 14  80        80                   1  Week              500  Milliliter (ml)
# 15  81        81                   1   Day                1        Liter (l)
# 16  85        85                   1   Day                1  Milliliter (ml)
# 17  86        86                   1   Day                1        Liter (l)
# 18  87        87                   1   Day                1  Milliliter (ml)
#
#    watering_time                             weather_condition  \
# 0          16:30                  Bright Sun,Rainy,Stormy Rain
# 1          09:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 2          08:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 3          08:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 4          07:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 5          07:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 6          08:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 7          08:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 8          08:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 9          07:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 10         06:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 11         07:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 12         06:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 13         06:30  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 14         07:00  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 15         01:00                                    Bright Sun
# 16         01:00                                    Bright Sun
# 17         12:00                                    Bright Sun
# 18         01:00                                    Bright Sun
#
#                                 condition_description  \
# 0                                    Sun,Rainy,Stormy
# 1   Water in the early morning or late afternoon.,...
# 2   Water early in the morning.,Maintain regular w...
# 3   Water in the early morning.,Maintain regular w...
# 4   Water in the early morning.,Maintain regular w...
# 5   Water early in the morning.,Maintain regular w...
# 6   Water in the early morning or late afternoon.,...
# 7   Water in the early morning or late afternoon.,...
# 8   Water early in the morning.,Maintain regular w...
# 9   Water in the early morning.,Maintain a regular...
# 10  Water in the morning to allow for absorption b...
# 11  Ensure orchids are shaded to prevent leaf burn...
# 12  Water early in the morning to prevent heat str...
# 13  Water early in the morning to prevent heat str...
# 14  Water early in the morning to prevent heat str...
# 15                                             gk ada
# 16    lebih baik dibiarkan karena akan tumbuh sendiri
# 17                                                  -
# 18                                                  -
#
#                    created_at                 updated_at
# 0  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 1  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 2  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 3  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 4  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 5  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 6  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 7  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 8  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 9  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 10 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 11 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 12 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 13 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 14 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 15 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 16 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 17 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 18 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123

# %%
df_dim_plant_reminders.rename(columns={'id': 'watering_reminders_id'}, inplace=True)
df_dim_watering_reminders = df_dim_plant_reminders
df_dim_watering_reminders
# Out:
#     watering_reminders_id  plant_id  watering_frequency  each  \
# 0                      61        61                   5  Week
# 1                      62        62                   3  Week
# 2                      63        63                   1  Week
# 3                      64        64                   4  Week
# 4                      65        65                   2  Week
# 5                      66        66                   1  Week
# 6                      67        67                   2  Week
# 7                      68        68                   2  Week
# 8                      69        69                   2  Week
# 9                      75        75                   3  Week
# 10                     76        76                   1  Week
# 11                     77        77                   1  Week
# 12                     78        78                   1  Week
# 13                     79        79                   1  Week
# 14                     80        80                   1  Week
# 15                     81        81                   1   Day
# 16                     85        85                   1   Day
# 17                     86        86                   1   Day
# 18                     87        87                   1   Day
#
#     watering_amount             unit watering_time  \
# 0               300        Liter (l)         16:30
# 1                 2        Liter (l)         09:00
# 2                 1        Liter (l)         08:00
# 3               500  Milliliter (ml)         08:30
# 4                 1        Liter (l)         07:30
# 5               500  Milliliter (ml)         07:30
# 6                 1        Liter (l)         08:00
# 7               500  Milliliter (ml)         08:00
# 8                 2        Liter (l)         08:00
# 9                 1        Liter (l)         07:30
# 10              500  Milliliter (ml)         06:30
# 11              500        Liter (l)         07:00
# 12                5        Liter (l)         06:00
# 13               10        Liter (l)         06:30
# 14              500  Milliliter (ml)         07:00
# 15                1        Liter (l)         01:00
# 16                1  Milliliter (ml)         01:00
# 17                1        Liter (l)         12:00
# 18                1  Milliliter (ml)         01:00
#
#                                weather_condition  \
# 0                   Bright Sun,Rainy,Stormy Rain
# 1   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 2   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 3   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 4   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 5   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 6   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 7   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 8   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 9   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 10  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 11  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 12  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 13  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 14  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 15                                    Bright Sun
# 16                                    Bright Sun
# 17                                    Bright Sun
# 18                                    Bright Sun
#
#                                 condition_description  \
# 0                                    Sun,Rainy,Stormy
# 1   Water in the early morning or late afternoon.,...
# 2   Water early in the morning.,Maintain regular w...
# 3   Water in the early morning.,Maintain regular w...
# 4   Water in the early morning.,Maintain regular w...
# 5   Water early in the morning.,Maintain regular w...
# 6   Water in the early morning or late afternoon.,...
# 7   Water in the early morning or late afternoon.,...
# 8   Water early in the morning.,Maintain regular w...
# 9   Water in the early morning.,Maintain a regular...
# 10  Water in the morning to allow for absorption b...
# 11  Ensure orchids are shaded to prevent leaf burn...
# 12  Water early in the morning to prevent heat str...
# 13  Water early in the morning to prevent heat str...
# 14  Water early in the morning to prevent heat str...
# 15                                             gk ada
# 16    lebih baik dibiarkan karena akan tumbuh sendiri
# 17                                                  -
# 18                                                  -
#
#                    created_at                 updated_at
# 0  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 1  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 2  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 3  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 4  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 5  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 6  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 7  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 8  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 9  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 10 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 11 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 12 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 13 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 14 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 15 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 16 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 17 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 18 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123

# %% [markdown]
# ##### a. Merged to Fact Table Plants Data

# %%
# Menggabungkan kedua dataframe
df_fact_plants_data = pd.merge(df_dim_watering_reminders, df_dim_plants, left_on="plant_id", right_on="plant_id", suffixes=('_watering_reminders', '_plant'))

# Menampilkan hasil gabungan
df_fact_plants_data.columns
# Out:
# Index(['watering_reminders_id', 'plant_id', 'watering_frequency', 'each',
#        'watering_amount', 'unit', 'watering_time', 'weather_condition',
#        'condition_description', 'created_at_watering_reminders',
#        'updated_at_watering_reminders', 'plant_name', 'description',
#        'is_toxic', 'harvest_duration', 'sunlight', 'planting_time',
#        'plant_category', 'climate_condition', 'additional_tips',
#        'created_at_plant', 'updated_at_plant'],
#       dtype='object')

# %%
df_fact_plants_data = df_fact_plants_data[['plant_id', 'watering_reminders_id']]
df_fact_plants_data
# Out:
#     plant_id  watering_reminders_id
# 0         61                     61
# 1         62                     62
# 2         63                     63
# 3         64                     64
# 4         65                     65
# 5         66                     66
# 6         67                     67
# 7         68                     68
# 8         69                     69
# 9         75                     75
# 10        76                     76
# 11        77                     77
# 12        78                     78
# 13        79                     79
# 14        80                     80
# 15        81                     81
# 16        85                     85
# 17        86                     86
# 18        87                     87

# %% [markdown]
# ##### b. Save to CSV

# %%
df_dim_plant_reminders = df_dim_plant_reminders[['watering_reminders_id', 'watering_frequency', 'each', 'watering_amount',
       'unit', 'watering_time', 'weather_condition', 'condition_description',
       'created_at', 'updated_at']]
df_dim_plant_reminders
# Out:
#     watering_reminders_id  watering_frequency  each  watering_amount  \
# 0                      61                   5  Week              300
# 1                      62                   3  Week                2
# 2                      63                   1  Week                1
# 3                      64                   4  Week              500
# 4                      65                   2  Week                1
# 5                      66                   1  Week              500
# 6                      67                   2  Week                1
# 7                      68                   2  Week              500
# 8                      69                   2  Week                2
# 9                      75                   3  Week                1
# 10                     76                   1  Week              500
# 11                     77                   1  Week              500
# 12                     78                   1  Week                5
# 13                     79                   1  Week               10
# 14                     80                   1  Week              500
# 15                     81                   1   Day                1
# 16                     85                   1   Day                1
# 17                     86                   1   Day                1
# 18                     87                   1   Day                1
#
#                unit watering_time  \
# 0         Liter (l)         16:30
# 1         Liter (l)         09:00
# 2         Liter (l)         08:00
# 3   Milliliter (ml)         08:30
# 4         Liter (l)         07:30
# 5   Milliliter (ml)         07:30
# 6         Liter (l)         08:00
# 7   Milliliter (ml)         08:00
# 8         Liter (l)         08:00
# 9         Liter (l)         07:30
# 10  Milliliter (ml)         06:30
# 11        Liter (l)         07:00
# 12        Liter (l)         06:00
# 13        Liter (l)         06:30
# 14  Milliliter (ml)         07:00
# 15        Liter (l)         01:00
# 16  Milliliter (ml)         01:00
# 17        Liter (l)         12:00
# 18  Milliliter (ml)         01:00
#
#                                weather_condition  \
# 0                   Bright Sun,Rainy,Stormy Rain
# 1   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 2   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 3   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 4   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 5   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 6   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 7   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 8   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 9   Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 10  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 11  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 12  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 13  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 14  Bright Sun,Part Cloudy Sun,Rainy,Stormy Rain
# 15                                    Bright Sun
# 16                                    Bright Sun
# 17                                    Bright Sun
# 18                                    Bright Sun
#
#                                 condition_description  \
# 0                                    Sun,Rainy,Stormy
# 1   Water in the early morning or late afternoon.,...
# 2   Water early in the morning.,Maintain regular w...
# 3   Water in the early morning.,Maintain regular w...
# 4   Water in the early morning.,Maintain regular w...
# 5   Water early in the morning.,Maintain regular w...
# 6   Water in the early morning or late afternoon.,...
# 7   Water in the early morning or late afternoon.,...
# 8   Water early in the morning.,Maintain regular w...
# 9   Water in the early morning.,Maintain a regular...
# 10  Water in the morning to allow for absorption b...
# 11  Ensure orchids are shaded to prevent leaf burn...
# 12  Water early in the morning to prevent heat str...
# 13  Water early in the morning to prevent heat str...
# 14  Water early in the morning to prevent heat str...
# 15                                             gk ada
# 16    lebih baik dibiarkan karena akan tumbuh sendiri
# 17                                                  -
# 18                                                  -
#
#                    created_at                 updated_at
# 0  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 1  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 2  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 3  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 4  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 5  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 6  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 7  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 8  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 9  2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 10 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 11 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 12 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 13 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 14 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 15 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 16 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 17 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123
# 18 2024-06-18 19:18:43.567171 2024-06-18 19:18:43.568123

# %%
df_dim_plant_reminders.to_csv('../data_source_to_load/dim_watering_reminders.csv', index=False)

# %% [markdown]
# #### 3.4.4.3 dim_plant_faqs

# %%
df_dim_plant_faqs
# Out:
#      id  plant_id                                           question  \
# 0    76        61                                      Mau tanya apa
# 1    77        62  Recommendation for fertilizer types and amount...
# 2    78        62  Recommendation for safe pest control to addres...
# 3    79        62                      How to improve tomato flavor?
# 4    80        62        How to prevent blossom end rot in tomatoes?
# 5    81        63  Recommendation for fertilizer types and amount...
# 6    82        63  Recommendation for safe pest control to addres...
# 7    83        63                     Can lavender be grown indoors?
# 8    84        63               How often should lavender be pruned?
# 9    85        64  Recommendation for fertilizer types and amount...
# 10   86        64  Recommendation for safe pest control to addres...
# 11   87        64  How often should basil be harvested? How often...
# 12   88        65  Recommendation for fertilizer types and amount...
# 13   89        65  Recommendation for safe pest control to addres...
# 14   90        65         When should strawberry plants be replaced?
# 15   91        65            How to protect strawberries from pests?
# 16   92        66  Recommendation for fertilizer types and amount...
# 17   93        66  Recommendation for safe pest control to addres...
# 18   94        66                 What are common pests of rosemary?
# 19   95        66                  How to propagate rosemary plants?
# 20   96        67  Recommendation for fertilizer types and amount...
# 21   97        67  Recommendation for safe pest control to addres...
# 22   98        67  When is the best time to harvest sunflower see...
# 23   99        67    How to deter birds from eating sunflower seeds?
# 24  100        68  Recommendation for fertilizer types and amount...
# 25  101        68  Recommendation for safe pest control to addres...
# 26  102        68  What are common pests and diseases of peppermint?
# 27  103        68  How to prevent peppermint from spreading uncon...
# 28  104        69  Recommendation for fertilizer types and amount...
# 29  105        69  Recommendation for safe pest control to addres...
# 30  106        69                How to prevent black spot on roses?
# 31  107        75  What type of fertilizer is recommended for cuc...
# 32  108        75  Recommendation for fertilizer types and amount...
# 33  109        75  Recommendation for safe pest control to addres...
# 34  110        75         How to deal with pests on cucumber plants?
# 35  111        76  What are the recommendations for fertilizer ty...
# 36  112        76  What are the recommendations for safe pest con...
# 37  113        76    What are common diseases that affect geraniums?
# 38  114        76          How do I propagate geraniums effectively?
# 39  115        77  How do I ensure my orchids thrive in low-humid...
# 40  116        77  What are the recommendations for fertilizer ty...
# 41  117        77  What are the recommendations for safe pest con...
# 42  118        77         Can orchids be grown indoors successfully?
# 43  119        77   How do I encourage orchids to bloom more freq...
# 44  120        78  What are the recommendations for fertilizer ty...
# 45  121        78  What are the recommendations for safe pest con...
# 46  122        78  When is the best time to prune lemon trees for...
# 47  123        78  How do I protect lemon trees from pests and di...
# 48  124        79  What are the recommendations for fertilizer ty...
# 49  125        79  What are the recommendations for safe pest con...
# 50  126        79  When is the best time to prune mango trees for...
# 51  127        79  How do I protect mango trees from pests and di...
# 52  128        80  What are the recommendations for fertilizer ty...
# 53  129        80  What are the recommendations for safe pest con...
# 54  130        80                      How do I propagate Aloe Vera?
# 55  131        80       Can Aloe Vera tolerate low light conditions?
# 56  132        81                  bagaimana cara alang alang tumbuh
# 57  133        85  Bagaimana cara alang alang dapat tumbuh tanpa ...
# 58  134        86                                                idk
# 59  135        87                        How to care for alang-alang
#
#                                                answer  \
# 0                                          Ya gatauu?
# 1   Use a balanced 10-10-10 fertilizer at planting...
# 2   Use neem oil or insecticidal soap to manage co...
# 3   Provide ample sunlight, avoid over-fertilizati...
# 4   Blossom end rot is caused by calcium deficienc...
# 5   Use a slow-release fertilizer with a higher ra...
# 6   Introduce beneficial insects like ladybugs to ...
# 7   Lavender can be grown indoors in containers wi...
# 8   Lavender should be lightly pruned after flower...
# 9   Use a balanced liquid fertilizer like 10-10-10...
# 10  Use diatomaceous earth around the base of plan...
# 11  Basil should be harvested regularly by pinchin...
# 12  Use a balanced fertilizer high in phosphorus b...
# 13  Use floating row covers to protect strawberrie...
# 14  Replace strawberry plants every 3-5 years to m...
# 15  Use floating row covers to keep out insects or...
# 16  Use a well-balanced fertilizer during the grow...
# 17  Use insecticidal soap or neem oil to control p...
# 18  Look out for spider mites and aphids. Use inse...
# 19  Propagate rosemary from cuttings taken in spri...
# 20  Apply a balanced fertilizer with equal parts n...
# 21  Protect sunflowers from pests like birds by co...
# 22  Wait until the back of the sunflower head turn...
# 23  Cover sunflower heads with fine mesh netting a...
# 24  Apply a nitrogen-rich fertilizer every 4-6 wee...
# 25  Use organic insecticides or neem oil to contro...
# 26  Look out for aphids and spider mites. Use inse...
# 27  Plant peppermint in containers or bury barrier...
# 28  Apply a rose-specific fertilizer with balanced...
# 29  Use organic sprays like insecticidal soap or h...
# 30  Ensure good air circulation around plants. App...
# 31  Use nitrogen-rich fertilizer to promote health...
# 32  Use a balanced fertilizer with higher nitrogen...
# 33  Use floating row covers to protect cucumbers f...
# 34  What type of fertilizer is recommended for cuc...
# 35  Apply a balanced, water-soluble fertilizer eve...
# 36  Use organic insecticidal soap or neem oil to m...
# 37  Watch for diseases like powdery mildew; ensure...
# 38  Propagate geraniums from stem cuttings in earl...
# 39  Use a humidity tray or room humidifier, and mi...
# 40  Use a balanced orchid fertilizer every 2 weeks...
# 41  Use insecticidal soap or rubbing alcohol on a ...
# 42  Yes, orchids thrive indoors with bright, indir...
# 43  Ensure orchids receive proper light, temperatu...
# 44  Apply a citrus-specific fertilizer every 6 wee...
# 45  Use horticultural oil or neem oil to control p...
# 46  Prune lemon trees lightly after harvesting fru...
# 47  Monitor for pests like aphids and scale insect...
# 48  Use a balanced fertilizer with a 6-6-6 or 8-3-...
# 49  Use neem oil or insecticidal soap to manage pe...
# 50  Prune mango trees lightly after harvesting fru...
# 51  Monitor for pests like mango leafhoppers and m...
# 52  Apply a diluted, balanced liquid fertilizer on...
# 53  Use a mild insecticidal soap or neem oil for p...
# 54  Propagate Aloe Vera by separating offsets (pup...
# 55   Aloe Vera prefers bright light but can tolera...
# 56                                             yntkts
# 57  alang alang merupakan tanaman liar dan dapat b...
# 58                                                idk
# 59   While it is drought-resistant once establishe...
#
#                    created_at                 updated_at
# 0  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 1  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 2  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 3  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 4  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 5  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 6  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 7  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 8  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 9  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 10 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 11 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 12 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 13 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 14 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 15 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 16 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 17 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 18 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 19 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 20 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 21 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 22 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 23 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 24 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 25 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 26 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 27 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 28 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 29 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 30 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 31 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 32 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 33 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 34 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 35 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 36 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 37 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 38 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 39 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 40 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 41 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 42 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 43 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 44 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 45 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 46 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 47 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 48 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 49 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 50 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 51 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 52 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 53 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 54 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 55 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 56 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 57 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 58 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 59 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761

# %%
df_dim_plant_faqs.rename(columns={'id': 'plant_faqs_id'}, inplace=True)
df_dim_plant_faqs
# Out:
#     plant_faqs_id  plant_id  \
# 0              76        61
# 1              77        62
# 2              78        62
# 3              79        62
# 4              80        62
# 5              81        63
# 6              82        63
# 7              83        63
# 8              84        63
# 9              85        64
# 10             86        64
# 11             87        64
# 12             88        65
# 13             89        65
# 14             90        65
# 15             91        65
# 16             92        66
# 17             93        66
# 18             94        66
# 19             95        66
# 20             96        67
# 21             97        67
# 22             98        67
# 23             99        67
# 24            100        68
# 25            101        68
# 26            102        68
# 27            103        68
# 28            104        69
# 29            105        69
# 30            106        69
# 31            107        75
# 32            108        75
# 33            109        75
# 34            110        75
# 35            111        76
# 36            112        76
# 37            113        76
# 38            114        76
# 39            115        77
# 40            116        77
# 41            117        77
# 42            118        77
# 43            119        77
# 44            120        78
# 45            121        78
# 46            122        78
# 47            123        78
# 48            124        79
# 49            125        79
# 50            126        79
# 51            127        79
# 52            128        80
# 53            129        80
# 54            130        80
# 55            131        80
# 56            132        81
# 57            133        85
# 58            134        86
# 59            135        87
#
#                                              question  \
# 0                                       Mau tanya apa
# 1   Recommendation for fertilizer types and amount...
# 2   Recommendation for safe pest control to addres...
# 3                       How to improve tomato flavor?
# 4         How to prevent blossom end rot in tomatoes?
# 5   Recommendation for fertilizer types and amount...
# 6   Recommendation for safe pest control to addres...
# 7                      Can lavender be grown indoors?
# 8                How often should lavender be pruned?
# 9   Recommendation for fertilizer types and amount...
# 10  Recommendation for safe pest control to addres...
# 11  How often should basil be harvested? How often...
# 12  Recommendation for fertilizer types and amount...
# 13  Recommendation for safe pest control to addres...
# 14         When should strawberry plants be replaced?
# 15            How to protect strawberries from pests?
# 16  Recommendation for fertilizer types and amount...
# 17  Recommendation for safe pest control to addres...
# 18                 What are common pests of rosemary?
# 19                  How to propagate rosemary plants?
# 20  Recommendation for fertilizer types and amount...
# 21  Recommendation for safe pest control to addres...
# 22  When is the best time to harvest sunflower see...
# 23    How to deter birds from eating sunflower seeds?
# 24  Recommendation for fertilizer types and amount...
# 25  Recommendation for safe pest control to addres...
# 26  What are common pests and diseases of peppermint?
# 27  How to prevent peppermint from spreading uncon...
# 28  Recommendation for fertilizer types and amount...
# 29  Recommendation for safe pest control to addres...
# 30                How to prevent black spot on roses?
# 31  What type of fertilizer is recommended for cuc...
# 32  Recommendation for fertilizer types and amount...
# 33  Recommendation for safe pest control to addres...
# 34         How to deal with pests on cucumber plants?
# 35  What are the recommendations for fertilizer ty...
# 36  What are the recommendations for safe pest con...
# 37    What are common diseases that affect geraniums?
# 38          How do I propagate geraniums effectively?
# 39  How do I ensure my orchids thrive in low-humid...
# 40  What are the recommendations for fertilizer ty...
# 41  What are the recommendations for safe pest con...
# 42         Can orchids be grown indoors successfully?
# 43   How do I encourage orchids to bloom more freq...
# 44  What are the recommendations for fertilizer ty...
# 45  What are the recommendations for safe pest con...
# 46  When is the best time to prune lemon trees for...
# 47  How do I protect lemon trees from pests and di...
# 48  What are the recommendations for fertilizer ty...
# 49  What are the recommendations for safe pest con...
# 50  When is the best time to prune mango trees for...
# 51  How do I protect mango trees from pests and di...
# 52  What are the recommendations for fertilizer ty...
# 53  What are the recommendations for safe pest con...
# 54                      How do I propagate Aloe Vera?
# 55       Can Aloe Vera tolerate low light conditions?
# 56                  bagaimana cara alang alang tumbuh
# 57  Bagaimana cara alang alang dapat tumbuh tanpa ...
# 58                                                idk
# 59                        How to care for alang-alang
#
#                                                answer  \
# 0                                          Ya gatauu?
# 1   Use a balanced 10-10-10 fertilizer at planting...
# 2   Use neem oil or insecticidal soap to manage co...
# 3   Provide ample sunlight, avoid over-fertilizati...
# 4   Blossom end rot is caused by calcium deficienc...
# 5   Use a slow-release fertilizer with a higher ra...
# 6   Introduce beneficial insects like ladybugs to ...
# 7   Lavender can be grown indoors in containers wi...
# 8   Lavender should be lightly pruned after flower...
# 9   Use a balanced liquid fertilizer like 10-10-10...
# 10  Use diatomaceous earth around the base of plan...
# 11  Basil should be harvested regularly by pinchin...
# 12  Use a balanced fertilizer high in phosphorus b...
# 13  Use floating row covers to protect strawberrie...
# 14  Replace strawberry plants every 3-5 years to m...
# 15  Use floating row covers to keep out insects or...
# 16  Use a well-balanced fertilizer during the grow...
# 17  Use insecticidal soap or neem oil to control p...
# 18  Look out for spider mites and aphids. Use inse...
# 19  Propagate rosemary from cuttings taken in spri...
# 20  Apply a balanced fertilizer with equal parts n...
# 21  Protect sunflowers from pests like birds by co...
# 22  Wait until the back of the sunflower head turn...
# 23  Cover sunflower heads with fine mesh netting a...
# 24  Apply a nitrogen-rich fertilizer every 4-6 wee...
# 25  Use organic insecticides or neem oil to contro...
# 26  Look out for aphids and spider mites. Use inse...
# 27  Plant peppermint in containers or bury barrier...
# 28  Apply a rose-specific fertilizer with balanced...
# 29  Use organic sprays like insecticidal soap or h...
# 30  Ensure good air circulation around plants. App...
# 31  Use nitrogen-rich fertilizer to promote health...
# 32  Use a balanced fertilizer with higher nitrogen...
# 33  Use floating row covers to protect cucumbers f...
# 34  What type of fertilizer is recommended for cuc...
# 35  Apply a balanced, water-soluble fertilizer eve...
# 36  Use organic insecticidal soap or neem oil to m...
# 37  Watch for diseases like powdery mildew; ensure...
# 38  Propagate geraniums from stem cuttings in earl...
# 39  Use a humidity tray or room humidifier, and mi...
# 40  Use a balanced orchid fertilizer every 2 weeks...
# 41  Use insecticidal soap or rubbing alcohol on a ...
# 42  Yes, orchids thrive indoors with bright, indir...
# 43  Ensure orchids receive proper light, temperatu...
# 44  Apply a citrus-specific fertilizer every 6 wee...
# 45  Use horticultural oil or neem oil to control p...
# 46  Prune lemon trees lightly after harvesting fru...
# 47  Monitor for pests like aphids and scale insect...
# 48  Use a balanced fertilizer with a 6-6-6 or 8-3-...
# 49  Use neem oil or insecticidal soap to manage pe...
# 50  Prune mango trees lightly after harvesting fru...
# 51  Monitor for pests like mango leafhoppers and m...
# 52  Apply a diluted, balanced liquid fertilizer on...
# 53  Use a mild insecticidal soap or neem oil for p...
# 54  Propagate Aloe Vera by separating offsets (pup...
# 55   Aloe Vera prefers bright light but can tolera...
# 56                                             yntkts
# 57  alang alang merupakan tanaman liar dan dapat b...
# 58                                                idk
# 59   While it is drought-resistant once establishe...
#
#                    created_at                 updated_at
# 0  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 1  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 2  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 3  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 4  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 5  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 6  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 7  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 8  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 9  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 10 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 11 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 12 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 13 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 14 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 15 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 16 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 17 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 18 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 19 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 20 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 21 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 22 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 23 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 24 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 25 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 26 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 27 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 28 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 29 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 30 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 31 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 32 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 33 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 34 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 35 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 36 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 37 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 38 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 39 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 40 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 41 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 42 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 43 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 44 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 45 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 46 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 47 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 48 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 49 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 50 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 51 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 52 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 53 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 54 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 55 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 56 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 57 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 58 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 59 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761

# %% [markdown]
# ##### a. Merged to Fact Table Plants Data

# %%
# Menggabungkan kedua dataframe
df_fact_plants_data = pd.merge(df_dim_plant_faqs, df_fact_plants_data, left_on="plant_id", right_on="plant_id", suffixes=('_faqs', '_fact'))

# Menampilkan hasil gabungan
df_fact_plants_data.columns
# Out:
# Index(['plant_faqs_id', 'plant_id', 'question', 'answer', 'created_at',
#        'updated_at', 'watering_reminders_id'],
#       dtype='object')

# %%
df_fact_plants_data = df_fact_plants_data[['plant_id', 'plant_faqs_id', 'watering_reminders_id']]
df_fact_plants_data
# Out:
#     plant_id  plant_faqs_id  watering_reminders_id
# 0         61             76                     61
# 1         62             77                     62
# 2         62             78                     62
# 3         62             79                     62
# 4         62             80                     62
# 5         63             81                     63
# 6         63             82                     63
# 7         63             83                     63
# 8         63             84                     63
# 9         64             85                     64
# 10        64             86                     64
# 11        64             87                     64
# 12        65             88                     65
# 13        65             89                     65
# 14        65             90                     65
# 15        65             91                     65
# 16        66             92                     66
# 17        66             93                     66
# 18        66             94                     66
# 19        66             95                     66
# 20        67             96                     67
# 21        67             97                     67
# 22        67             98                     67
# 23        67             99                     67
# 24        68            100                     68
# 25        68            101                     68
# 26        68            102                     68
# 27        68            103                     68
# 28        69            104                     69
# 29        69            105                     69
# 30        69            106                     69
# 31        75            107                     75
# 32        75            108                     75
# 33        75            109                     75
# 34        75            110                     75
# 35        76            111                     76
# 36        76            112                     76
# 37        76            113                     76
# 38        76            114                     76
# 39        77            115                     77
# 40        77            116                     77
# 41        77            117                     77
# 42        77            118                     77
# 43        77            119                     77
# 44        78            120                     78
# 45        78            121                     78
# 46        78            122                     78
# 47        78            123                     78
# 48        79            124                     79
# 49        79            125                     79
# 50        79            126                     79
# 51        79            127                     79
# 52        80            128                     80
# 53        80            129                     80
# 54        80            130                     80
# 55        80            131                     80
# 56        81            132                     81
# 57        85            133                     85
# 58        86            134                     86
# 59        87            135                     87

# %% [markdown]
# ##### b. Save to CSV

# %%
df_dim_plant_faqs = df_dim_plant_faqs[['plant_faqs_id', 'question', 'answer',
       'created_at', 'updated_at']]
df_dim_plant_faqs
# Out:
#     plant_faqs_id                                           question  \
# 0              76                                      Mau tanya apa
# 1              77  Recommendation for fertilizer types and amount...
# 2              78  Recommendation for safe pest control to addres...
# 3              79                      How to improve tomato flavor?
# 4              80        How to prevent blossom end rot in tomatoes?
# 5              81  Recommendation for fertilizer types and amount...
# 6              82  Recommendation for safe pest control to addres...
# 7              83                     Can lavender be grown indoors?
# 8              84               How often should lavender be pruned?
# 9              85  Recommendation for fertilizer types and amount...
# 10             86  Recommendation for safe pest control to addres...
# 11             87  How often should basil be harvested? How often...
# 12             88  Recommendation for fertilizer types and amount...
# 13             89  Recommendation for safe pest control to addres...
# 14             90         When should strawberry plants be replaced?
# 15             91            How to protect strawberries from pests?
# 16             92  Recommendation for fertilizer types and amount...
# 17             93  Recommendation for safe pest control to addres...
# 18             94                 What are common pests of rosemary?
# 19             95                  How to propagate rosemary plants?
# 20             96  Recommendation for fertilizer types and amount...
# 21             97  Recommendation for safe pest control to addres...
# 22             98  When is the best time to harvest sunflower see...
# 23             99    How to deter birds from eating sunflower seeds?
# 24            100  Recommendation for fertilizer types and amount...
# 25            101  Recommendation for safe pest control to addres...
# 26            102  What are common pests and diseases of peppermint?
# 27            103  How to prevent peppermint from spreading uncon...
# 28            104  Recommendation for fertilizer types and amount...
# 29            105  Recommendation for safe pest control to addres...
# 30            106                How to prevent black spot on roses?
# 31            107  What type of fertilizer is recommended for cuc...
# 32            108  Recommendation for fertilizer types and amount...
# 33            109  Recommendation for safe pest control to addres...
# 34            110         How to deal with pests on cucumber plants?
# 35            111  What are the recommendations for fertilizer ty...
# 36            112  What are the recommendations for safe pest con...
# 37            113    What are common diseases that affect geraniums?
# 38            114          How do I propagate geraniums effectively?
# 39            115  How do I ensure my orchids thrive in low-humid...
# 40            116  What are the recommendations for fertilizer ty...
# 41            117  What are the recommendations for safe pest con...
# 42            118         Can orchids be grown indoors successfully?
# 43            119   How do I encourage orchids to bloom more freq...
# 44            120  What are the recommendations for fertilizer ty...
# 45            121  What are the recommendations for safe pest con...
# 46            122  When is the best time to prune lemon trees for...
# 47            123  How do I protect lemon trees from pests and di...
# 48            124  What are the recommendations for fertilizer ty...
# 49            125  What are the recommendations for safe pest con...
# 50            126  When is the best time to prune mango trees for...
# 51            127  How do I protect mango trees from pests and di...
# 52            128  What are the recommendations for fertilizer ty...
# 53            129  What are the recommendations for safe pest con...
# 54            130                      How do I propagate Aloe Vera?
# 55            131       Can Aloe Vera tolerate low light conditions?
# 56            132                  bagaimana cara alang alang tumbuh
# 57            133  Bagaimana cara alang alang dapat tumbuh tanpa ...
# 58            134                                                idk
# 59            135                        How to care for alang-alang
#
#                                                answer  \
# 0                                          Ya gatauu?
# 1   Use a balanced 10-10-10 fertilizer at planting...
# 2   Use neem oil or insecticidal soap to manage co...
# 3   Provide ample sunlight, avoid over-fertilizati...
# 4   Blossom end rot is caused by calcium deficienc...
# 5   Use a slow-release fertilizer with a higher ra...
# 6   Introduce beneficial insects like ladybugs to ...
# 7   Lavender can be grown indoors in containers wi...
# 8   Lavender should be lightly pruned after flower...
# 9   Use a balanced liquid fertilizer like 10-10-10...
# 10  Use diatomaceous earth around the base of plan...
# 11  Basil should be harvested regularly by pinchin...
# 12  Use a balanced fertilizer high in phosphorus b...
# 13  Use floating row covers to protect strawberrie...
# 14  Replace strawberry plants every 3-5 years to m...
# 15  Use floating row covers to keep out insects or...
# 16  Use a well-balanced fertilizer during the grow...
# 17  Use insecticidal soap or neem oil to control p...
# 18  Look out for spider mites and aphids. Use inse...
# 19  Propagate rosemary from cuttings taken in spri...
# 20  Apply a balanced fertilizer with equal parts n...
# 21  Protect sunflowers from pests like birds by co...
# 22  Wait until the back of the sunflower head turn...
# 23  Cover sunflower heads with fine mesh netting a...
# 24  Apply a nitrogen-rich fertilizer every 4-6 wee...
# 25  Use organic insecticides or neem oil to contro...
# 26  Look out for aphids and spider mites. Use inse...
# 27  Plant peppermint in containers or bury barrier...
# 28  Apply a rose-specific fertilizer with balanced...
# 29  Use organic sprays like insecticidal soap or h...
# 30  Ensure good air circulation around plants. App...
# 31  Use nitrogen-rich fertilizer to promote health...
# 32  Use a balanced fertilizer with higher nitrogen...
# 33  Use floating row covers to protect cucumbers f...
# 34  What type of fertilizer is recommended for cuc...
# 35  Apply a balanced, water-soluble fertilizer eve...
# 36  Use organic insecticidal soap or neem oil to m...
# 37  Watch for diseases like powdery mildew; ensure...
# 38  Propagate geraniums from stem cuttings in earl...
# 39  Use a humidity tray or room humidifier, and mi...
# 40  Use a balanced orchid fertilizer every 2 weeks...
# 41  Use insecticidal soap or rubbing alcohol on a ...
# 42  Yes, orchids thrive indoors with bright, indir...
# 43  Ensure orchids receive proper light, temperatu...
# 44  Apply a citrus-specific fertilizer every 6 wee...
# 45  Use horticultural oil or neem oil to control p...
# 46  Prune lemon trees lightly after harvesting fru...
# 47  Monitor for pests like aphids and scale insect...
# 48  Use a balanced fertilizer with a 6-6-6 or 8-3-...
# 49  Use neem oil or insecticidal soap to manage pe...
# 50  Prune mango trees lightly after harvesting fru...
# 51  Monitor for pests like mango leafhoppers and m...
# 52  Apply a diluted, balanced liquid fertilizer on...
# 53  Use a mild insecticidal soap or neem oil for p...
# 54  Propagate Aloe Vera by separating offsets (pup...
# 55   Aloe Vera prefers bright light but can tolera...
# 56                                             yntkts
# 57  alang alang merupakan tanaman liar dan dapat b...
# 58                                                idk
# 59   While it is drought-resistant once establishe...
#
#                    created_at                 updated_at
# 0  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 1  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 2  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 3  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 4  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 5  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 6  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 7  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 8  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 9  2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 10 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 11 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 12 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 13 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 14 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 15 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 16 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 17 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 18 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 19 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 20 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 21 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 22 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 23 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 24 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 25 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 26 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 27 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 28 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 29 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 30 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 31 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 32 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 33 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 34 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 35 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 36 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 37 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 38 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 39 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 40 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 41 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 42 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 43 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 44 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 45 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 46 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 47 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 48 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 49 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 50 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 51 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 52 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 53 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 54 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 55 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 56 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 57 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 58 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761
# 59 2024-06-18 19:18:43.392587 2024-06-18 19:18:43.393761

# %%
df_dim_plant_faqs.to_csv('../data_source_to_load/dim_plant_faqs.csv', index=False)

# %% [markdown]
# #### 3.4.4.4 dim_plant_instructions

# %%
df_dim_plant_instructions
# Out:
#      id  plant_id  step_number            step_title  \
# 0    92        61            1                 Apaya
# 1    93        62            1    Preparing the soil
# 2    94        62            2   Sowing tomato seeds
# 3    95        62            3     Tomato Plant Care
# 4    96        62            4   Harvesting Tomatoes
# ..  ...       ...          ...                   ...
# 56  168        80            4  Harvesting Aloe Vera
# 57  169        81            1                gk tau
# 58  173        85            1          Cara Merawat
# 59  174        86            1    Preparing the Soil
# 60  175        87            1                     -
#
#                                      step_description  \
# 0                                         enaknya apa
# 1   Prepare well-draining soil rich in organic mat...
# 2   Sow tomato seeds indoors 6-8 weeks before the ...
# 3   Water regularly to keep the soil moist but not...
# 4   Harvest tomatoes when they are fully colored a...
# ..                                                ...
# 56  Harvest mature leaves as needed by cutting the...
# 57                        biarkan tumbuh secara alami
# 58  Biarkan terkena matahari sepanjang hari dan be...
# 59  Use fertile soil with good drainage. Incorpora...
# 60                        How to care for Alang-Alang
#
#                                        step_image_url additional_tips  \
# 0   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 1   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 2   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 3   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 4   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# ..                                                ...             ...
# 56  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 57                                                  -               -
# 58  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 59  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 60  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
#
#                    created_at                 updated_at  \
# 0  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 1  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 2  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 3  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 4  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# ..                        ...                        ...
# 56 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 57 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 58 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 59 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 60 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
#
#     instruction_category_id
# 0                         3
# 1                         1
# 2                         2
# 3                         3
# 4                         4
# ..                      ...
# 56                        4
# 57                        2
# 58                        3
# 59                        1
# 60                        3
#
# [61 rows x 10 columns]

# %%
df_dim_plant_instructions.rename(columns={'id': 'plant_instruction_id'}, inplace=True)
df_dim_plant_instructions
# Out:
#     plant_instruction_id  plant_id  step_number            step_title  \
# 0                     92        61            1                 Apaya
# 1                     93        62            1    Preparing the soil
# 2                     94        62            2   Sowing tomato seeds
# 3                     95        62            3     Tomato Plant Care
# 4                     96        62            4   Harvesting Tomatoes
# ..                   ...       ...          ...                   ...
# 56                   168        80            4  Harvesting Aloe Vera
# 57                   169        81            1                gk tau
# 58                   173        85            1          Cara Merawat
# 59                   174        86            1    Preparing the Soil
# 60                   175        87            1                     -
#
#                                      step_description  \
# 0                                         enaknya apa
# 1   Prepare well-draining soil rich in organic mat...
# 2   Sow tomato seeds indoors 6-8 weeks before the ...
# 3   Water regularly to keep the soil moist but not...
# 4   Harvest tomatoes when they are fully colored a...
# ..                                                ...
# 56  Harvest mature leaves as needed by cutting the...
# 57                        biarkan tumbuh secara alami
# 58  Biarkan terkena matahari sepanjang hari dan be...
# 59  Use fertile soil with good drainage. Incorpora...
# 60                        How to care for Alang-Alang
#
#                                        step_image_url additional_tips  \
# 0   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 1   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 2   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 3   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 4   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# ..                                                ...             ...
# 56  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 57                                                  -               -
# 58  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 59  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 60  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
#
#                    created_at                 updated_at  \
# 0  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 1  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 2  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 3  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 4  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# ..                        ...                        ...
# 56 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 57 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 58 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 59 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 60 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
#
#     instruction_category_id
# 0                         3
# 1                         1
# 2                         2
# 3                         3
# 4                         4
# ..                      ...
# 56                        4
# 57                        2
# 58                        3
# 59                        1
# 60                        3
#
# [61 rows x 10 columns]

# %%
df_dim_plant_instruction_categories.rename(columns={'id': 'instruction_category_id'}, inplace=True)
df_dim_plant_instruction_categories
# Out:
#    instruction_category_id              name  \
# 0                        1  Soil Preparation
# 1                        2    Planting Seeds
# 2                        3        Plant Care
# 3                        4           Harvest
#
#                                          description  \
# 0  In this section, you will learn how to properl...
# 1  At this stage, you will learn how to properly ...
# 2  In this section, you will learn how to properl...
# 3  At this stage, you will learn how to harvest p...
#
#                                            image_url  \
# 0  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 1  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 2  https://res.cloudinary.com/dxrz0cg5z/image/upl...
# 3  https://res.cloudinary.com/dxrz0cg5z/image/upl...
#
#                   created_at                 updated_at
# 0 2024-06-18 19:18:43.525201 2024-06-18 19:18:43.526034
# 1 2024-06-18 19:18:43.525201 2024-06-18 19:18:43.526034
# 2 2024-06-18 19:18:43.525201 2024-06-18 19:18:43.526034
# 3 2024-06-18 19:18:43.525201 2024-06-18 19:18:43.526034

# %%
# Melakukan merge dalam satu baris kode dengan suffixes untuk menghindari konflik kolom
df_dim_plant_instructions = df_dim_plant_instructions.merge(
    df_dim_plant_instruction_categories, on='instruction_category_id', how='left', suffixes=('', '_category'))

# Memeriksa nama kolom setelah merge
print(df_dim_plant_instructions.columns)
# Out:
# Index(['plant_instruction_id', 'plant_id', 'step_number', 'step_title',
#        'step_description', 'step_image_url', 'additional_tips', 'created_at',
#        'updated_at', 'instruction_category_id', 'name', 'description',
#        'image_url', 'created_at_category', 'updated_at_category'],
#       dtype='object')

# %%
df_dim_plant_instructions = df_dim_plant_instructions[['plant_instruction_id', 'name', 'plant_id', 'step_number', 'step_title',
       'step_description', 'step_image_url', 'additional_tips', 'created_at',
       'updated_at']]

df_dim_plant_instructions.rename(columns={'name': 'name_instruction_categories'}, inplace=True)

df_dim_plant_instructions
# Out:
#     plant_instruction_id name_instruction_categories  plant_id  step_number  \
# 0                     92                  Plant Care        61            1
# 1                     93            Soil Preparation        62            1
# 2                     94              Planting Seeds        62            2
# 3                     95                  Plant Care        62            3
# 4                     96                     Harvest        62            4
# ..                   ...                         ...       ...          ...
# 56                   168                     Harvest        80            4
# 57                   169              Planting Seeds        81            1
# 58                   173                  Plant Care        85            1
# 59                   174            Soil Preparation        86            1
# 60                   175                  Plant Care        87            1
#
#               step_title                                   step_description  \
# 0                  Apaya                                        enaknya apa
# 1     Preparing the soil  Prepare well-draining soil rich in organic mat...
# 2    Sowing tomato seeds  Sow tomato seeds indoors 6-8 weeks before the ...
# 3      Tomato Plant Care  Water regularly to keep the soil moist but not...
# 4    Harvesting Tomatoes  Harvest tomatoes when they are fully colored a...
# ..                   ...                                                ...
# 56  Harvesting Aloe Vera  Harvest mature leaves as needed by cutting the...
# 57                gk tau                        biarkan tumbuh secara alami
# 58          Cara Merawat  Biarkan terkena matahari sepanjang hari dan be...
# 59    Preparing the Soil  Use fertile soil with good drainage. Incorpora...
# 60                     -                        How to care for Alang-Alang
#
#                                        step_image_url additional_tips  \
# 0   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 1   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 2   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 3   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 4   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# ..                                                ...             ...
# 56  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 57                                                  -               -
# 58  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 59  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 60  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
#
#                    created_at                 updated_at
# 0  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 1  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 2  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 3  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 4  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# ..                        ...                        ...
# 56 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 57 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 58 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 59 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 60 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
#
# [61 rows x 10 columns]

# %% [markdown]
# ##### a. Merged to Fact Table Plants Data

# %%
# Menggabungkan kedua dataframe
df_fact_plants_data = pd.merge(df_dim_plant_instructions, df_fact_plants_data, left_on="plant_id", 
                               right_on="plant_id", suffixes=('_instructions', '_fact'))

# Menampilkan hasil gabungan
df_fact_plants_data.columns
# Out:
# Index(['plant_instruction_id', 'name_instruction_categories', 'plant_id',
#        'step_number', 'step_title', 'step_description', 'step_image_url',
#        'additional_tips', 'created_at', 'updated_at', 'plant_faqs_id',
#        'watering_reminders_id'],
#       dtype='object')

# %%
df_fact_plants_data = df_fact_plants_data[['plant_id', 'plant_faqs_id', 'plant_instruction_id', 'watering_reminders_id']]

df_fact_plants_data
# Out:
#      plant_id  plant_faqs_id  plant_instruction_id  watering_reminders_id
# 0          61             76                    92                     61
# 1          62             77                    93                     62
# 2          62             78                    93                     62
# 3          62             79                    93                     62
# 4          62             80                    93                     62
# ..        ...            ...                   ...                    ...
# 220        80            131                   168                     80
# 221        81            132                   169                     81
# 222        85            133                   173                     85
# 223        86            134                   174                     86
# 224        87            135                   175                     87
#
# [225 rows x 4 columns]

# %% [markdown]
# ##### b. Save to CSV

# %%
df_dim_plant_instructions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   plant_instruction_id         61 non-null     int64
#  1   name_instruction_categories  61 non-null     category
#  2   plant_id                     61 non-null     int64
#  3   step_number                  61 non-null     int64
#  4   step_title                   61 non-null     category
#  5   step_description             61 non-null     category
#  6   step_image_url               61 non-null     category
#  7   additional_tips              61 non-null     category
#  8   created_at                   61 non-null     datetime64[ns]
#  9   updated_at                   61 non-null     datetime64[ns]
# dtypes: category(5), datetime64[ns](2), int64(3)
# memory usage: 10.6 KB

# %%
df_dim_plant_instructions = df_dim_plant_instructions[['plant_instruction_id', 'name_instruction_categories', 'step_number', 'step_title',
       'step_description', 'step_image_url', 'additional_tips', 'created_at',
       'updated_at']]
df_dim_plant_instructions
# Out:
#     plant_instruction_id name_instruction_categories  step_number  \
# 0                     92                  Plant Care            1
# 1                     93            Soil Preparation            1
# 2                     94              Planting Seeds            2
# 3                     95                  Plant Care            3
# 4                     96                     Harvest            4
# ..                   ...                         ...          ...
# 56                   168                     Harvest            4
# 57                   169              Planting Seeds            1
# 58                   173                  Plant Care            1
# 59                   174            Soil Preparation            1
# 60                   175                  Plant Care            1
#
#               step_title                                   step_description  \
# 0                  Apaya                                        enaknya apa
# 1     Preparing the soil  Prepare well-draining soil rich in organic mat...
# 2    Sowing tomato seeds  Sow tomato seeds indoors 6-8 weeks before the ...
# 3      Tomato Plant Care  Water regularly to keep the soil moist but not...
# 4    Harvesting Tomatoes  Harvest tomatoes when they are fully colored a...
# ..                   ...                                                ...
# 56  Harvesting Aloe Vera  Harvest mature leaves as needed by cutting the...
# 57                gk tau                        biarkan tumbuh secara alami
# 58          Cara Merawat  Biarkan terkena matahari sepanjang hari dan be...
# 59    Preparing the Soil  Use fertile soil with good drainage. Incorpora...
# 60                     -                        How to care for Alang-Alang
#
#                                        step_image_url additional_tips  \
# 0   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 1   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 2   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 3   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 4   https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# ..                                                ...             ...
# 56  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 57                                                  -               -
# 58  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 59  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
# 60  https://res.cloudinary.com/dxrz0cg5z/image/upl...               -
#
#                    created_at                 updated_at
# 0  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 1  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 2  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 3  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 4  2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# ..                        ...                        ...
# 56 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 57 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 58 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 59 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
# 60 2024-06-18 19:18:43.313241 2024-06-18 19:18:43.313956
#
# [61 rows x 9 columns]

# %%
df_dim_plant_instructions.to_csv('../data_source_to_load/dim_plant_instructions.csv', index=False)

# %% [markdown]
# #### 3.4.4.5 dim_plant_characteristics

# %%
df_dim_plant_characteristics
# Out:
#     id  plant_id  height height_unit  wide   wide_unit leaf_color
# 0   61        61       3       Meter   300  Centimeter        Red
# 1   62        62       2       Meter     1       Meter      Green
# 2   63        63     600  Centimeter   900  Centimeter      Green
# 3   64        64     400  Centimeter   300  Centimeter      Green
# 4   65        65     200  Centimeter   300  Centimeter      Green
# 5   66        66    1200  Centimeter   600  Centimeter      Green
# 6   67        67       2       Meter     1       Meter      Green
# 7   68        68     500  Centimeter   300  Centimeter      Green
# 8   69        69     150  Centimeter    75  Centimeter      Green
# 9   75        75     500  Centimeter   400  Centimeter      Green
# 10  76        76      45  Centimeter    40  Centimeter      Green
# 11  77        77     100  Centimeter    30  Centimeter      Green
# 12  78        78       6       Meter     4       Meter      Green
# 13  79        79      20       Meter     8       Meter      Green
# 14  80        80      60  Centimeter    40  Centimeter      Green
# 15  81        81       1  Centimeter     1  Centimeter     Yellow
# 16  85        85       1  Centimeter     1  Centimeter     Yellow
# 17  86        86       1       Meter     4  Centimeter      Green
# 18  87        87       1  Centimeter     1  Centimeter     Yellow

# %%
df_dim_plant_characteristics.rename(columns={'id': 'plant_characteristic_id'}, inplace=True)
df_dim_plant_characteristics
# Out:
#     plant_characteristic_id  plant_id  height height_unit  wide   wide_unit  \
# 0                        61        61       3       Meter   300  Centimeter
# 1                        62        62       2       Meter     1       Meter
# 2                        63        63     600  Centimeter   900  Centimeter
# 3                        64        64     400  Centimeter   300  Centimeter
# 4                        65        65     200  Centimeter   300  Centimeter
# 5                        66        66    1200  Centimeter   600  Centimeter
# 6                        67        67       2       Meter     1       Meter
# 7                        68        68     500  Centimeter   300  Centimeter
# 8                        69        69     150  Centimeter    75  Centimeter
# 9                        75        75     500  Centimeter   400  Centimeter
# 10                       76        76      45  Centimeter    40  Centimeter
# 11                       77        77     100  Centimeter    30  Centimeter
# 12                       78        78       6       Meter     4       Meter
# 13                       79        79      20       Meter     8       Meter
# 14                       80        80      60  Centimeter    40  Centimeter
# 15                       81        81       1  Centimeter     1  Centimeter
# 16                       85        85       1  Centimeter     1  Centimeter
# 17                       86        86       1       Meter     4  Centimeter
# 18                       87        87       1  Centimeter     1  Centimeter
#
#    leaf_color
# 0         Red
# 1       Green
# 2       Green
# 3       Green
# 4       Green
# 5       Green
# 6       Green
# 7       Green
# 8       Green
# 9       Green
# 10      Green
# 11      Green
# 12      Green
# 13      Green
# 14      Green
# 15     Yellow
# 16     Yellow
# 17      Green
# 18     Yellow

# %% [markdown]
# ##### a. Merged to Fact Table Plants Data

# %%
# Menggabungkan kedua dataframe
df_fact_plants_data = pd.merge(df_dim_plant_characteristics, df_fact_plants_data, left_on="plant_id", 
                               right_on="plant_id", suffixes=('_characteristics', '_fact'))

# Menampilkan hasil gabungan
df_fact_plants_data.columns
# Out:
# Index(['plant_characteristic_id', 'plant_id', 'height', 'height_unit', 'wide',
#        'wide_unit', 'leaf_color', 'plant_faqs_id', 'plant_instruction_id',
#        'watering_reminders_id'],
#       dtype='object')

# %%
df_fact_plants_data = df_fact_plants_data[['plant_id', 'plant_faqs_id', 'plant_characteristic_id', 'plant_instruction_id', 'watering_reminders_id']]

df_fact_plants_data
# Out:
#      plant_id  plant_faqs_id  plant_characteristic_id  plant_instruction_id  \
# 0          61             76                       61                    92
# 1          62             77                       62                    93
# 2          62             78                       62                    93
# 3          62             79                       62                    93
# 4          62             80                       62                    93
# ..        ...            ...                      ...                   ...
# 220        80            131                       80                   168
# 221        81            132                       81                   169
# 222        85            133                       85                   173
# 223        86            134                       86                   174
# 224        87            135                       87                   175
#
#      watering_reminders_id
# 0                       61
# 1                       62
# 2                       62
# 3                       62
# 4                       62
# ..                     ...
# 220                     80
# 221                     81
# 222                     85
# 223                     86
# 224                     87
#
# [225 rows x 5 columns]

# %% [markdown]
# ##### b. Save to CSV

# %%
df_dim_plant_characteristics = df_dim_plant_characteristics[['plant_characteristic_id', 'height', 'height_unit', 'wide',
       'wide_unit', 'leaf_color']]

df_dim_plant_characteristics
# Out:
#     plant_characteristic_id  height height_unit  wide   wide_unit leaf_color
# 0                        61       3       Meter   300  Centimeter        Red
# 1                        62       2       Meter     1       Meter      Green
# 2                        63     600  Centimeter   900  Centimeter      Green
# 3                        64     400  Centimeter   300  Centimeter      Green
# 4                        65     200  Centimeter   300  Centimeter      Green
# 5                        66    1200  Centimeter   600  Centimeter      Green
# 6                        67       2       Meter     1       Meter      Green
# 7                        68     500  Centimeter   300  Centimeter      Green
# 8                        69     150  Centimeter    75  Centimeter      Green
# 9                        75     500  Centimeter   400  Centimeter      Green
# 10                       76      45  Centimeter    40  Centimeter      Green
# 11                       77     100  Centimeter    30  Centimeter      Green
# 12                       78       6       Meter     4       Meter      Green
# 13                       79      20       Meter     8       Meter      Green
# 14                       80      60  Centimeter    40  Centimeter      Green
# 15                       81       1  Centimeter     1  Centimeter     Yellow
# 16                       85       1  Centimeter     1  Centimeter     Yellow
# 17                       86       1       Meter     4  Centimeter      Green
# 18                       87       1  Centimeter     1  Centimeter     Yellow

# %%
df_dim_plant_characteristics.to_csv('../data_source_to_load/dim_plant_characteristics.csv', index=False)

# %% [markdown]
# #### 3.4.4.6 Merged Fact Table Plants Data Final

# %%
# Menghitung total_plants
df_fact_plants_data['total_plants'] = df_fact_plants_data['plant_id'].nunique()
df_fact_plants_data
# Out:
#      plant_id  plant_faqs_id  plant_characteristic_id  plant_instruction_id  \
# 0          61             76                       61                    92
# 1          62             77                       62                    93
# 2          62             78                       62                    93
# 3          62             79                       62                    93
# 4          62             80                       62                    93
# ..        ...            ...                      ...                   ...
# 220        80            131                       80                   168
# 221        81            132                       81                   169
# 222        85            133                       85                   173
# 223        86            134                       86                   174
# 224        87            135                       87                   175
#
#      watering_reminders_id  total_plants
# 0                       61            19
# 1                       62            19
# 2                       62            19
# 3                       62            19
# 4                       62            19
# ..                     ...           ...
# 220                     80            19
# 221                     81            19
# 222                     85            19
# 223                     86            19
# 224                     87            19
#
# [225 rows x 6 columns]

# %% [markdown]
# ##### a. Save to CSV

# %%
df_fact_plants_data.to_csv('../data_source_to_load/fact_plants_data.csv', index=False)

# %% [markdown]
# # 4. Load

# %%
load_dotenv()

project_id = os.getenv('PROJECT_ID')
dataset_id = os.getenv('DATASET_ID')
service_acc = os.getenv('SERVICE_ACCOUNT')

os.environ['SERVICE_ACCOUNT'] = service_acc

credentials = service_account.Credentials.from_service_account_file(service_acc)

client = bigquery.Client(credentials=credentials, project=project_id)

def load_csv_to_bigquery(csv_file_path, table_id):
    # Baca file CSV ke DataFrame
    df = pd.read_csv(csv_file_path)

    # Bersihkan DataFrame
    df_cleaned = cleanse_dataframe(df)
    
    df_cleaned = change_type_data(df)

    # Tentukan ID tabel penuh: dataset_id.table_name
    table_id = f"{project_id}.{dataset_id}.{table_id}"
    
    # Muat DataFrame ke tabel BigQuery
    job = client.load_table_from_dataframe(df_cleaned, table_id)
    
    # Tunggu pekerjaan selesai
    job.result()
    
    print(f"Loaded {len(df_cleaned)} rows into {table_id}.")

# Direktori tempat file CSV Anda berada
data_source_dir = '../data_source_to_load'

# Muat setiap file CSV di direktori tersebut ke tabel BigQuery yang sesuai
for csv_file in os.listdir(data_source_dir):
    if csv_file.endswith('.csv'):
        csv_file_path = os.path.join(data_source_dir, csv_file)
        table_name = os.path.splitext(csv_file)[0]  # Nama tabel diambil dari nama file tanpa ekstensi
        load_csv_to_bigquery(csv_file_path, table_name)
# Out:
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'name_instruction_categories'...
# Membersihkan tag HTML di kolom 'step_title'...
# Membersihkan tag HTML di kolom 'step_description'...
# Membersihkan tag HTML di kolom 'step_image_url'...
# Membersihkan tag HTML di kolom 'additional_tips'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# Loaded 61 rows into plantopia-capstone.plantopia.dim_plant_instructions.
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'time'...
# Membersihkan tag HTML di kolom 'type'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# Loaded 2 rows into plantopia-capstone.plantopia.dim_customize_watering_reminders.
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'user_name'...
# Membersihkan tag HTML di kolom 'plant_name'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# Loaded 1 rows into plantopia-capstone.plantopia.dim_watering_histories.
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'question'...
# Membersihkan tag HTML di kolom 'answer'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# Loaded 60 rows into plantopia-capstone.plantopia.dim_plant_faqs.
# Memeriksa missing values...
# Mengisi missing values di kolom 'last_watered_at' dengan 0...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'user_name'...
# Membersihkan tag HTML di kolom 'plant_name'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'last_watered_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'last_watered_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# /tmp/ipykernel_70970/889720400.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(0, inplace=True)
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# Loaded 10 rows into plantopia-capstone.plantopia.dim_my_plants.
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'user_name'...
# Membersihkan tag HTML di kolom 'plant_name'...
# Membersihkan tag HTML di kolom 'plant_category'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# Loaded 29 rows into plantopia-capstone.plantopia.dim_planting_histories.
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Memastikan tipe data yang benar...
# Loaded 31 rows into plantopia-capstone.plantopia.fact_user_activities.
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'height_unit'...
# Membersihkan tag HTML di kolom 'wide_unit'...
# Membersihkan tag HTML di kolom 'leaf_color'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Memastikan tipe data yang benar...
# /home/newrey/.local/lib/python3.10/site-packages/google/cloud/bigquery/_pandas_helpers.py:570: UserWarning: Pyarrow could not determine the type of columns: height_unit, wide_unit, leaf_color.
#   warnings.warn(
# Loaded 19 rows into plantopia-capstone.plantopia.dim_plant_characteristics.
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'plant_name'...
# Membersihkan tag HTML di kolom 'description'...
# Membersihkan tag HTML di kolom 'sunlight'...
# Membersihkan tag HTML di kolom 'planting_time'...
# Membersihkan tag HTML di kolom 'plant_category'...
# Membersihkan tag HTML di kolom 'climate_condition'...
# Membersihkan tag HTML di kolom 'additional_tips'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# Loaded 19 rows into plantopia-capstone.plantopia.dim_plants.
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Memastikan tipe data yang benar...
# Loaded 225 rows into plantopia-capstone.plantopia.fact_plants_data.
# Memeriksa missing values...
# Membersihkan tag HTML dari kolom teks...
# Membersihkan tag HTML di kolom 'each'...
# Membersihkan tag HTML di kolom 'unit'...
# Membersihkan tag HTML di kolom 'watering_time'...
# Membersihkan tag HTML di kolom 'weather_condition'...
# Membersihkan tag HTML di kolom 'condition_description'...
# Membersihkan tag HTML di kolom 'created_at'...
# Membersihkan tag HTML di kolom 'updated_at'...
# Memeriksa duplikasi...
# Jumlah baris duplikat: 0
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Memastikan tipe data yang benar...
# Mengonversi kolom 'created_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# Mengonversi kolom 'updated_at' menjadi datetime dengan format '%Y-%m-%d %H:%M'...
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['created_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# /tmp/ipykernel_70970/628058250.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['updated_at'].fillna(datetime.now(), inplace=True)  # Isi dengan tanggal dan waktu saat ini
# Loaded 19 rows into plantopia-capstone.plantopia.dim_watering_reminders.
